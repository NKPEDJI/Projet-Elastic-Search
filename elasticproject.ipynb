# %%
import requests
import json
import csv
import json
from pprint import pprint



class ElasticSearchToCassandra:

    def __init__(self) -> None:
        self.files_to_download = [
            "time_series_covid19_confirmed_global",
            "time_series_covid19_recovered_global",
            "time_series_covid19_deaths_global",
         ]


    def download_csv_files(self):
        url = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/"
        for endpoint in self.files_to_download:
            response = requests.get(f"{url}{endpoint}.csv")

            response.raise_for_status()
            with open(f"{endpoint}.csv", "w") as f:
                f.write(response.text)


    def convert_csv_to_json(self):
        for filename in self.files_to_download:
            data_list = []
            with open(f"{filename}.csv", encoding = 'utf-8') as csv_file_handler:
                csv_reader = csv.DictReader(csv_file_handler)
        
                for rows in csv_reader:
                    data_list.append(rows)
        
            with open(f"{filename}.json", 'w', encoding = 'utf-8') as json_file_handler:
                json_file_handler.write(json.dumps(data_list, indent = 4))


    def aggregate_json(self):
        year_2020 = 0
        year_2021 = 0
        year_2022 = 0
        year_2023 = 0

        final_dict = {}

        for filename in self.files_to_download:
            with open(f"{filename}.json", "r") as f:
                json_file = f.read()

                for line in json.loads(json_file):
                    line_dict = {}
                    for k, v in line.items():
                        if k.endswith("/20"):
                            year_2020+=int(v)
                        elif k.endswith("/21"):
                            year_2021+=int(v)
                        elif k.endswith("/22"):
                            year_2022+=int(v)
                        elif k.endswith("/23"):
                            year_2023+=int(v)
                        else:
                            line_dict[k] = v
                        
                    line_dict["2020"] = year_2020
                    line_dict["2021"] = year_2021
                    line_dict["2022"] = year_2022
                    line_dict["2023"] = year_2023
                    
                    final_dict.setdefault(filename, []).append(line_dict)

        return final_dict
                
if __name__ == "__main__":

    elasticsearch_to_cassandra_loader = ElasticSearchToCassandra()

    elasticsearch_to_cassandra_loader.download_csv_files()
    elasticsearch_to_cassandra_loader.convert_csv_to_json()
    data =  elasticsearch_to_cassandra_loader.aggregate_json()
    print(data)
# Out:
# {'time_series_covid19_confirmed_global': [{'Province/State': '', 'Country/Region': 'Afghanistan', 'Lat': '33.93911', 'Long': '67.709953', '2020': 8501751, '2021': 39518380, '2022': 67783564, '2023': 14184774}, {'Province/State': '', 'Country/Region': 'Albania', 'Lat': '41.1533', 'Long': '20.1683', '2020': 12229295, '2021': 90624521, '2022': 175788238, '2023': 36909069}, {'Province/State': '', 'Country/Region': 'Algeria', 'Lat': '28.0339', 'Long': '1.6596', '2020': 22812670, '2021': 147797509, '2022': 272320311, '2023': 55362283}, {'Province/State': '', 'Country/Region': 'Andorra', 'Lat': '42.5063', 'Long': '1.5218', '2020': 23495492, '2021': 152881839, '2022': 287848049, '2023': 58614918}, {'Province/State': '', 'Country/Region': 'Angola', 'Lat': '-11.2027', 'Long': '17.8739', '2020': 24838902, '2021': 167678984, '2022': 324581126, '2023': 65766489}, {'Province/State': '', 'Country/Region': 'Antarctica', 'Lat': '-71.9499', 'Long': '23.347', '2020': 24838902, '2021': 167679182, '2022': 324585141, '2023': 65767237}, {'Province/State': '', 'Country/Region': 'Antigua and Barbuda', 'Lat': '17.0608', 'Long': '-61.7964', '2020': 24861804, '2021': 168368620, '2022': 327563848, '2023': 66386445}, {'Province/State': '', 'Country/Region': 'Argentina', 'Lat': '-38.4161', 'Long': '-63.6167', '2020': 173198225, '2021': 1608579680, '2022': 3682802830, '2023': 748082903}, {'Province/State': '', 'Country/Region': 'Armenia', 'Lat': '40.0691', 'Long': '45.0382', '2020': 187751302, '2021': 1694821197, '2022': 3837153028, '2023': 778429434}, {'Province/State': 'Australian Capital Territory', 'Country/Region': 'Australia', 'Lat': '-35.4735', 'Long': '149.0124', '2020': 187782417, '2021': 1695058000, '2022': 3889218227, '2023': 794098837}, {'Province/State': 'New South Wales', 'Country/Region': 'Australia', 'Lat': '-33.8688', 'Long': '151.2093', '2020': 188844816, '2021': 1706093814, '2022': 4848556205, '2023': 1057760677}, {'Province/State': 'Northern Territory', 'Country/Region': 'Australia', 'Lat': '-12.4634', 'Long': '130.8456', '2020': 188854935, '2021': 1706161190, '2022': 4874775205, '2023': 1064859140}, {'Province/State': 'Queensland', 'Country/Region': 'Australia', 'Lat': '-27.4698', 'Long': '153.0251', '2020': 189166671, '2021': 1706847652, '2022': 5310430512, '2023': 1186044799}, {'Province/State': 'South Australia', 'Country/Region': 'Australia', 'Lat': '-34.9285', 'Long': '138.6007', '2020': 189299507, '2021': 1707183741, '2022': 5503728060, '2023': 1245502894}, {'Province/State': 'Tasmania', 'Country/Region': 'Australia', 'Lat': '-42.8821', 'Long': '147.3272', '2020': 189360961, '2021': 1707272207, '2022': 5566228114, '2023': 1264849786}, {'Province/State': 'Victoria', 'Country/Region': 'Australia', 'Lat': '-37.8136', 'Long': '144.9631', '2020': 192656986, '2021': 1722881158, '2022': 6280325819, '2023': 1459543357}, {'Province/State': 'Western Australia', 'Country/Region': 'Australia', 'Lat': '-31.9505', 'Long': '115.8605', '2020': 192842526, '2021': 1723254820, '2022': 6544218087, '2023': 1546704409}, {'Province/State': '', 'Country/Region': 'Austria', 'Lat': '47.5162', 'Long': '14.5501', '2020': 214614435, '2021': 1972025880, '2022': 8088996373, '2023': 1941840788}, {'Province/State': '', 'Country/Region': 'Azerbaijan', 'Lat': '40.1431', 'Long': '47.5769', '2020': 227563467, '2021': 2109451731, '2022': 8375872024, '2023': 1998136915}, {'Province/State': '', 'Country/Region': 'Bahamas', 'Lat': '25.025885', 'Long': '-78.035889', '2020': 228337073, '2021': 2114801477, '2022': 8388701429, '2023': 2000686303}, {'Province/State': '', 'Country/Region': 'Bahrain', 'Lat': '26.0275', 'Long': '50.55', '2020': 241266779, '2021': 2194468209, '2022': 8605666451, '2023': 2048431526}, {'Province/State': '', 'Country/Region': 'Bangladesh', 'Lat': '23.685', 'Long': '90.3563', '2020': 310076257, '2021': 2581952099, '2022': 9320186589, '2023': 2186985701}, {'Province/State': '', 'Country/Region': 'Barbados', 'Lat': '13.1939', 'Long': '-59.5432', '2020': ...

# %%
# get all data form elastic as curl 
import requests #curl
from requests.auth import HTTPBasicAuth 
from pprint import pprint
from elasticsearch import Elasticsearch,helpers
import json
import uuid

'''
generator to push bulk data from a JSON
file into an Elasticsearch index
'''

def bulk_json_data(json_list, _index, doc_type):
    for doc in json_list:
        # use a `yield` generator so that the data
        # isn't loaded into memory
        pprint(doc)
        if '{"index"' not in doc:
            yield {
                "_index": _index,
                "_type": doc_type,
                "_id": uuid.uuid4(),
                "_source": doc
            }

def connect_elastic():
    elastic = Elasticsearch('http://localhost:9200', http_auth=('elastic', 'secret'), timeout=30)
    return elastic

elastic = connect_elastic()

#elastic.delete_by_query(index='_all', body={"query": {"match_all": {}}})

def json_to_elastic(data_list):
    """
    covid_db_recovered_global
    covid_db_deaths_global
    covid_db_confirmed_global
    """
    for key in data_list.keys():
        doc_type = '_'.join(key.split('_')[-2:])
        try:
            response = helpers.bulk(elastic, bulk_json_data(data_list[key], f"covid_db_{doc_type}", doc_type), chunk_size=1000)
            print ("\nRESPONSE:", response)
        except Exception as e:
            print("\nERROR:", e)
            
json_to_elastic(data)
# Out:
# {'2020': 8501751,
#  '2021': 39518380,
#  '2022': 67783564,
#  '2023': 14184774,
#  'Country/Region': 'Afghanistan',
#  'Lat': '33.93911',
#  'Long': '67.709953',
#  'Province/State': ''}
# {'2020': 12229295,
#  '2021': 90624521,
#  '2022': 175788238,
#  '2023': 36909069,
#  'Country/Region': 'Albania',
#  'Lat': '41.1533',
#  'Long': '20.1683',
#  'Province/State': ''}
# {'2020': 22812670,
#  '2021': 147797509,
#  '2022': 272320311,
#  '2023': 55362283,
#  'Country/Region': 'Algeria',
#  'Lat': '28.0339',
#  'Long': '1.6596',
#  'Province/State': ''}
# {'2020': 23495492,
#  '2021': 152881839,
#  '2022': 287848049,
#  '2023': 58614918,
#  'Country/Region': 'Andorra',
#  'Lat': '42.5063',
#  'Long': '1.5218',
#  'Province/State': ''}
# {'2020': 24838902,
#  '2021': 167678984,
#  '2022': 324581126,
#  '2023': 65766489,
#  'Country/Region': 'Angola',
#  'Lat': '-11.2027',
#  'Long': '17.8739',
#  'Province/State': ''}
# {'2020': 24838902,
#  '2021': 167679182,
#  '2022': 324585141,
#  '2023': 65767237,
#  'Country/Region': 'Antarctica',
#  'Lat': '-71.9499',
#  'Long': '23.347',
#  'Province/State': ''}
# {'2020': 24861804,
#  '2021': 168368620,
#  '2022': 327563848,
#  '2023': 66386445,
#  'Country/Region': 'Antigua and Barbuda',
#  'Lat': '17.0608',
#  'Long': '-61.7964',
#  'Province/State': ''}
# {'2020': 173198225,
#  '2021': 1608579680,
#  '2022': 3682802830,
#  '2023': 748082903,
#  'Country/Region': 'Argentina',
#  'Lat': '-38.4161',
#  'Long': '-63.6167',
#  'Province/State': ''}
# {'2020': 187751302,
#  '2021': 1694821197,
#  '2022': 3837153028,
#  '2023': 778429434,
#  'Country/Region': 'Armenia',
#  'Lat': '40.0691',
#  'Long': '45.0382',
#  'Province/State': ''}
# {'2020': 187782417,
#  '2021': 1695058000,
#  '2022': 3889218227,
#  '2023': 794098837,
#  'Country/Region': 'Australia',
#  'Lat': '-35.4735',
#  'Long': '149.0124',
#  'Province/State': 'Australian Capital Territory'}
# {'2020': 188844816,
#  '2021': 1706093814,
#  '2022': 4848556205,
#  '2023': 1057760677,
#  'Country/Region': 'Australia',
#  'Lat': '-33.8688',
#  'Long': '151.2093',
#  'Province/State': 'New South Wales'}
# {'2020': 188854935,
#  '2021': 1706161190,
#  '2022': 4874775205,
#  '2023': 1064859140,
#  'Country/Region': 'Australia',
#  'Lat': '-12.4634',
#  'Long': '130.8456',
#  'Province/State': 'Northern Territory'}
# {'2020': 189166671,
#  '2021': 1706847652,
#  '2022': 5310430512,
#  '2023': 1186044799,
#  'Country/Region': 'Australia',
#  'Lat': '-27.4698',
#  'Long': '153.0251',
#  'Province/State': 'Queensland'}
# {'2020': 189299507,
#  '2021': 1707183741,
#  '2022': 5503728060,
#  '2023': 1245502894,
#  'Country/Region': 'Australia',
#  'Lat': '-34.9285',
#  'Long': '138.6007',
#  'Province/State': 'South Australia'}
# {'2020': 189360961,
#  '2021': 1707272207,
#  '2022': 5566228114,
#  '2023': 1264849786,
#  'Country/Region': 'Australia',
#  'Lat': '-42.8821',
#  'Long': '147.3272',
#  'Province/State': 'Tasmania'}
# {'2020': 192656986,
#  '2021': 1722881158,
#  '2022': 6280325819,
#  '2023': 1459543357,
#  'Country/Region': 'Australia',
#  'Lat': '-37.8136',
#  'Long': '144.9631',
#  'Province/State': 'Victoria'}
# {'2020': 192842526,
#  '2021': 1723254820,
#  '2022': 6544218087,
#  '2023': 1546704409,
#  'Country/Region': 'Australia',
#  'Lat': '-31.9505',
#  'Long': '115.8605',
#  'Province/State': 'Western Australia'}
# {'2020': 214614435,
#  '2021': 1972025880,
#  '2022': 8088996373,
#  '2023': 1941840788,
#  'Country/Region': 'Austria',
#  'Lat': '47.5162',
#  'Long': '14.5501',
#  'Province/State': ''}
# {'2020': 227563467,
#  '2021': 2109451731,
#  '2022': 8375872024,
#  '2023': 1998136915,
#  'Country/Region': 'Azerbaijan',
#  'Lat': '40.1431',
#  'Long': '47.5769',
#  'Province/State': ''}
# {'2020': 228337073,
#  '2021': 2114801477,
#  '2022': 8388701429,
#  '2023': 2000686303,
#  'Country/Region': 'Bahamas',
#  'Lat': '25.025885',
#  'Long': '-78.035889',
#  'Province/State': ''}
# {'2020': 241266779,
#  '2021': 2194468209,
#  '2022': 8605666451,
#  '2023': 2048431526,
#  'Country/Region': 'Bahrain',
#  'Lat': '26.0275',
#  'Long': '50.55',
#  'Province/State': ''}
# {'2020': 310076257,
#  '2021': 2581952099,
#  '2022': 9320186589,
#  '2023': 2186985701,
#  'Country/Region': 'Bangladesh',
#  'Lat': '23.685',
#  'Long': '90.3563',
#  'Province/State': ''}
# {'2020': 310121486,
#  '2021': 2584877804,
#  '2022': 9349642058,
#  '2023': 2194207788,
#  'Country/Region': 'Barbados',
#  'Lat': '13.1939',
#  'Long': '-59.5432',
#  'Province/State': ''}
# {'2020': 330552444,
#  '2021': 2743538896,
#  '2022': 9696606589,
#  '2023': 2261802304,
#  'Country/Region': 'Belarus',
#  'Lat': '53.7098',
#  'Long': '27.9534',
#  'Province/State': ''}
# {'2020': 384384477,
#  '2021': 3156642426,
#  '2022': 11190671468,
#  '2023': 2581299511,
#  'Country/Region': 'Belgium',
#  'Lat': '50.8333',
#  'Long': '4.469936',
#  'Province/State': ''}
# {'2020': 384959374,
#  '2021': 3162904097,
#  '2022': 11213210322,
#  '2023': 2586099016,
#  'Country/Region': 'Belize',
#  'Lat': '17.1899',
#  'Long': '-88.4976',
#  'Province/State': ''}
# {'2020': 385421510,
#  '2021': 3167525897,
#  '2022': 11223126622,
#  '2023': 2588002220,
#  'Country/Region': 'Benin',
#  'Lat': '9.3077',
#  'Long': '2.3158',
#  'Province/State': ''}
# {'2020': 385474950,
#  '2021': 3168200060,
#  '2022': 11240472581,
#  '2023': 2592258453,
#  'Country/Region': 'Bhutan',
#  'Lat': '27.5142',
#  'Long': '90.4336',
#  'Province/State': ''}
# {'2020': 408103446,
#  '2021': 3312883551,
#  '2022': 11598251932,
#  '2023': 2672879719,
#  'Country/Region': 'Bolivia',
#  'Lat': '-16.2902',
#  'Long': '-63.5887',
#  'Province/State': ''}
# {'2020': 416153084,
#  '2021': 3386499772,
#  '2022': 11736865111,
#  '2023': 2700173871,
#  'Country/Region': 'Bosnia and Herzegovina',
#  'Lat': '43.9159',
#  'Long': '17.6791',
#  'Province/State': ''}
# {'2020': 417087036,
#  '2021': 3423352151,
#  '2022': 11847857880,
#  '2023': 2722550759,
#  'Country/Region': 'Botswana',
#  'Lat': '-22.3285',
#  'Long': '24.6849',
#  'Province/State': ''}
# {'2020': 1309435143,
#  '2021': 9631760364,
#  '2022': 23426308192,
#  '2023': 5226034721,
#  'Country/Region': 'Brazil',
#  'Lat': '-14.235',
#  'Long': '-51.9253',
#  'Province/State': ''}
# {'2020': 1309476370,
#  '2021': 9633208647,
#  '2022': 23486374097,
#  '2023': 5244747718,
#  'Country/Region': 'Brunei',
#  'Lat': '4.5353',
#  'Long': '114.7277',
#  'Province/State': ''}
# {'2020': 1320572227,
#  '2021': 9792120729,
#  '2022': 23911894162,
#  '2023': 5332831150,
#  'Country/Region': 'Bulgaria',
#  'Lat': '42.7339',
#  'Long': '25.4858',
#  'Province/State': ''}
# {'2020': 1321058484,
#  '2021': 9797008609,
#  '2022': 23919574029,
#  '2023': 5334329469,
#  'Country/Region': 'Burkina Faso',
#  'Lat': '12.2383',
#  'Long': '-1.5616',
#  'Province/State': ''}
# {'2020': 1327843310,
#  '2021': 9900444616,
#  '2022': 24140920924,
#  '2023': 5377429991,
#  'Country/Region': 'Burma',
#  'Lat': '21.9162',
#  'Long': '95.956',
#  'Province/State': ''}
# {'2020': 1327942123,
#  '2021': 9903826148,
#  '2022': 24156983985,
#  '2023': 5381035694,
#  'Country/Region': 'Burundi',
#  'Lat': '-3.3731',
#  'Long': '29.9189',
#  'Province/State': ''}
# {'2020': 1329163193,
#  '2021': 9914287432,
#  '2022': 24178539151,
#  '2023': 5385335263,
#  'Country/Region': 'Cabo Verde',
#  'Lat': '16.5388',
#  'Long': '-23.0418',
#  'Province/State': ''}
# {'2020': 1329226587,
#  '2021': 9935099929,
#  '2022': 24227648945,
#  '2023': 5394765747,
#  'Country/Region': 'Cambodia',
#  'Lat': '11.55',
#  'Long': '104.9167',
#  'Province/State': ''}
# {'2020': 1333458528,
#  '2021': 9961961116,
#  '2022': 24271485107,
#  '2023': 5403204005,
#  'Country/Region': 'Cameroon',
#  'Lat': '3.848',
#  'Long': '11.5021',
#  'Province/State': ''}
# {'2020': 1339594545,
#  '2021': 10045268643,
#  '2022': 24479545629,
#  '2023': 5445824747,
#  'Country/Region': 'Canada',
#  'Lat': '53.9333',
#  'Long': '-116.5765',
#  'Province/State': 'Alberta'}
# {'2020': 1342650477,
#  '2021': 10098410895,
#  '2022': 24613170203,
#  '2023': 5472672563,
#  'Country/Region': 'Canada',
#  'Lat': '53.7267',
#  'Long': '-127.6476',
#  'Province/State': 'British Columbia'}
# {'2020': 1342650509,
#  '2021': 10098410895,
#  '2022': 24613170203,
#  '2023': 5472672563,
#  'Country/Region': 'Canada',
#  'Lat': '0.0',
#  'Long': '0.0',
#  'Province/State': 'Diamond Princess'}
# {'2020': 1342654268,
#  '2021': 10098415640,
#  '2022': 24613174948,
#  '2023': 5472673447,
#  'Country/Region': 'Canada',
#  'Lat': '0.0',
#  'Long': '0.0',
#  'Province/State': 'Grand Princess'}
# {'2020': 1343861863,
#  '2021': 10116717491,
#  '2022': 24664559329,
#  '2023': 5483154627,
#  'Country/Region': 'Canada',
#  'Lat': '53.7609',
#  'Long': '-98.8139',
#  'Province/State': 'Manitoba'}
# {'2020': 1343928779,
#  '2021': 10117981540,
#  '2022': 24687334409,
#  '2023': 5489076640,
#  'Country/Region': 'Canada',
#  'Lat': '46.5653',
#  'Long': '-66.4619',
#  'Province/State': 'New Brunswick'}
# {'2020': 1344006710,
#  '2021': 10118483265,
#  '2022': 24702770883,
#  '2023': 5492771994,
#  'Country/Region': 'Canada',
#  'Lat': '53.1355',
#  'Long': '-57.6604',
#  'Province/State': 'Newfoundland and Labrador'}
# {'2020': 1344008854,
#  '2021': 10118700160,
#  '2022': 24706558627,
#  '2023': 5493554742,
#  'Country/Region': 'Canada',
#  'Lat': '64.8255',
#  'Long': '-124.8457',
#  'Province/State': 'Northwest Territories'}
# {'2020': 1344302483,
#  '2021': 10120567797,
#  '2022': 24740910156,
#  '2023': 5502949708,
#  'Country/Region': 'Canada',
#  'Lat': '44.682',
#  'Long': '-63.7443',
#  'Province/State': 'Nova Scotia'}
# {'2020': 1344311900,
#  '2021': 10120770881,
#  '2022': 24742081948,
#  '2023': 5503189816,
#  'Country/Region': 'Canada',
#  'Lat': '70.2998',
#  'Long': '-83.1076',
#  'Province/State': 'Nunavut'}
# {'2020': 1359975913,
#  '2021': 10300868279,
#  '2022': 25223591349,
#  '2023': 5610606847,
#  'Country/Region': 'Canada',
#  'Lat': '51.2538',
#  'Long': '-85.3232',
#  'Province/State': 'Ontario'}
# {'2020': 1359989001,
#  '2021': 10300952897,
#  '2022': 25237208849,
#  '2023': 5614424091,
#  'Country/Region': 'Canada',
#  'Lat': '46.5107',
#  'Long': '-63.4168',
#  'Province/State': 'Prince Edward Island'}
# {'2020': 1381114748,
#  '2021': 10434682458,
#  '2022': 25631559781,
#  '2023': 5703107583,
#  'Country/Region': 'Canada',
#  'Lat': '52.9399',
#  'Long': '-73.5491',
#  'Province/State': 'Quebec'}
# {'2020': 1381115242,
#  '2021': 10434687203,
#  '2022': 25631564526,
#  '2023': 5703108467,
#  'Country/Region': 'Canada',
#  'Lat': '',
#  'Long': '',
#  'Province/State': 'Repatriated Travellers'}
# {'2020': 1381912184,
#  '2021': 10453113327,
#  '2022': 25681201775,
#  '2023': 5713468591,
#  'Country/Region': 'Canada',
#  'Lat': '52.9399',
#  'Long': '-106.4509',
#  'Province/State': 'Saskatchewan'}
# {'2020': 1381917618,
#  '2021': 10453300205,
#  '2022': 25682765405,
#  '2023': 5713807843,
#  'Country/Region': 'Canada',
#  'Lat': '64.2823',
#  'Long': '-135.0',
#  'Province/State': 'Yukon'}
# {'2020': 1382872567,
#  '2021': 10456296780,
#  '2022': 25688111996,
#  '2023': 5714852506,
#  'Country/Region': 'Central African Republic',
#  'Lat': '6.6111',
#  'Long': '20.9394',
#  'Province/State': ''}
# {'2020': 1383150470,
#  '2021': 10458005307,
#  '2022': 25690810071,
#  '2023': 5715373331,
#  'Country/Region': 'Chad',
#  'Lat': '15.4542',
#  'Long': '18.7322',
#  'Province/State': ''}
# {'2020': 1475597919,
#  '2021': 10954410372,
#  '2022': 27106548287,
#  '2023': 6063652355,
#  'Country/Region': 'Chile',
#  'Lat': '-35.6751',
#  'Long': '-71.543',
#  'Province/State': ''}
# {'2020': 1475926061,
#  '2021': 10954776213,
#  '2022': 27107018623,
#  '2023': 6063803441,
#  'Country/Region': 'China',
#  'Lat': '31.8257',
#  'Long': '117.2264',
#  'Province/State': 'Anhui'}
# {'2020': 1476182601,
#  '2021': 10955175239,
#  '2022': 27108904169,
#  '2023': 6066560314,
#  'Country/Region': 'China',
#  'Lat': '40.1824',
#  'Long': '116.4142',
#  'Province/State': 'Beijing'}
# {'2020': 1476376435,
#  '2021': 10955393948,
#  '2022': 27109524971,
#  '2023': 6067555591,
#  'Country/Region': 'China',
#  'Lat': '30.0572',
#  'Long': '107.874',
#  'Province/State': 'Chongqing'}
# {'2020': 1476503601,
#  '2021': 10955696108,
#  '2022': 27110869909,
#  '2023': 6068696889,
#  'Country/Region': 'China',
#  'Lat': '26.0789',
#  'Long': '117.9874',
#  'Province/State': 'Fujian'}
# {'2020': 1476554713,
#  '2021': 10955776617,
#  '2022': 27111214555,
#  '2023': 6068814261,
#  'Country/Region': 'China',
#  'Lat': '35.7518',
#  'Long': '104.2861',
#  'Province/State': 'Gansu'}
# {'2020': 1477116038,
#  '2021': 10956769254,
#  '2022': 27115896186,
#  '2023': 6075763888,
#  'Country/Region': 'China',
#  'Lat': '23.3417',
#  'Long': '113.4244',
#  'Province/State': 'Guangdong'}
# {'2020': 1477201135,
#  '2021': 10956881079,
#  '2022': 27116545846,
#  '2023': 6076625871,
#  'Country/Region': 'China',
#  'Lat': '23.8298',
#  'Long': '108.7881',
#  'Province/State': 'Guangxi'}
# {'2020': 1477249555,
#  '2021': 10956935550,
#  '2022': 27116712859,
#  '2023': 6076795404,
#  'Country/Region': 'China',
#  'Lat': '26.8154',
#  'Long': '106.8748',
#  'Province/State': 'Guizhou'}
# {'2020': 1477305986,
#  '2021': 10957002619,
#  '2022': 27118045412,
#  '2023': 6077508154,
#  'Country/Region': 'China',
#  'Lat': '19.1959',
#  'Long': '109.7453',
#  'Province/State': 'Hainan'}
# {'2020': 1477420301,
#  '2021': 10957479467,
#  '2022': 27118768936,
#  '2023': 6077731059,
#  'Country/Region': 'China',
#  'Lat': '39.549',
#  'Long': '116.1306',
#  'Province/State': 'Hebei'}
# {'2020': 1477701389,
#  '2021': 10958081798,
#  '2022': 27119889401,
#  '2023': 6078176909,
#  'Country/Region': 'China',
#  'Lat': '47.862',
#  'Long': '127.7615',
#  'Province/State': 'Heilongjiang'}
# {'2020': 1478125498,
#  '2021': 10958598948,
#  '2022': 27121227441,
#  '2023': 6078850870,
#  'Country/Region': 'China',
#  'Lat': '37.8957',
#  'Long': '114.9042',
#  'Province/State': 'Henan'}
# {'2020': 1479141910,
#  '2021': 10962868758,
#  '2022': 27585748081,
#  '2023': 6272373886,
#  'Country/Region': 'China',
#  'Lat': '22.3',
#  'Long': '114.2',
#  'Province/State': 'Hong Kong'}
# {'2020': 1501311989,
#  '2021': 10987767925,
#  '2022': 27610737597,
#  '2023': 6277274350,
#  'Country/Region': 'China',
#  'Lat': '30.9756',
#  'Long': '112.2707',
#  'Province/State': 'Hubei'}
# {'2020': 1501650683,
#  '2021': 10988170998,
#  '2022': 27611298623,
#  '2023': 6277768976,
#  'Country/Region': 'China',
#  'Lat': '27.6104',
#  'Long': '111.7088',
#  'Province/State': 'Hunan'}
# {'2020': 1501725808,
#  '2021': 10988344193,
#  '2022': 27612371075,
#  '2023': 6278369095,
#  'Country/Region': 'China',
#  'Lat': '44.0935',
#  'Long': '113.9448',
#  'Province/State': 'Inner Mongolia'}
# {'2020': 1501943565,
#  '2021': 10988739013,
#  '2022': 27613227547,
#  '2023': 6278706225,
#  'Country/Region': 'China',
#  'Lat': '32.9711',
#  'Long': '119.455',
#  'Province/State': 'Jiangsu'}
# {'2020': 1502253257,
#  '2021': 10989082074,
#  '2022': 27613713252,
#  '2023': 6278935462,
#  'Country/Region': 'China',
#  'Lat': '27.614',
#  'Long': '115.7221',
#  'Province/State': 'Jiangxi'}
# {'2020': 1502299281,
#  '2021': 10989282718,
#  '2022': 27625117675,
#  '2023': 6281706530,
#  'Country/Region': 'China',
#  'Lat': '43.6661',
#  'Long': '126.1923',
#  'Province/State': 'Jilin'}
# {'2020': 1502368068,
#  '2021': 10989455935,
#  '2022': 27625740743,
#  '2023': 6281946684,
#  'Country/Region': 'China',
#  'Lat': '41.2956',
#  'Long': '122.6085',
#  'Province/State': 'Liaoning'}
# {'2020': 1502381507,
#  '2021': 10989477447,
#  '2022': 27625917040,
#  '2023': 6282179343,
#  'Country/Region': 'China',
#  'Lat': '22.1667',
#  'Long': '113.55',
#  'Province/State': 'Macau'}
# {'2020': 1502406214,
#  '2021': 10989508176,
#  '2022': 27625971356,
#  '2023': 6282263105,
#  'Country/Region': 'China',
#  'Lat': '37.2692',
#  'Long': '106.1655',
#  'Province/State': 'Ningxia'}
# {'2020': 1502412255,
#  '2021': 10989515496,
#  '2022': 27626034698,
#  '2023': 6282315437,
#  'Country/Region': 'China',
#  'Lat': '35.7452',
#  'Long': '95.9956',
#  'Province/State': 'Qinghai'}
# {'2020': 1502529346,
#  '2021': 10989752387,
#  '2022': 27627342836,
#  '2023': 6282809344,
#  'Country/Region': 'China',
#  'Lat': '35.1917',
#  'Long': '108.8701',
#  'Province/State': 'Shaanxi'}
# {'2020': 1502793998,
#  '2021': 10990085791,
#  '2022': 27628326697,
#  '2023': 6283204407,
#  'Country/Region': 'China',
#  'Lat': '36.3427',
#  'Long': '118.1498',
#  'Province/State': 'Shandong'}
# {'2020': 1503067504,
#  '2021': 10990907774,
#  '2022': 27645127113,
#  '2023': 6287760626,
#  'Country/Region': 'China',
#  'Lat': '31.202',
#  'Long': '121.4491',
#  'Province/State': 'Shanghai'}
# {'2020': 1503131003,
#  '2021': 10990999590,
#  '2022': 27645480455,
#  '2023': 6288243458,
#  'Country/Region': 'China',
#  'Lat': '37.5777',
#  'Long': '112.2922',
#  'Province/State': 'Shanxi'}
# {'2020': 1503342820,
#  '2021': 10991394569,
#  '2022': 27646887869,
#  '2023': 6289228451,
#  'Country/Region': 'China',
#  'Lat': '30.6171',
#  'Long': '102.7103',
#  'Province/State': 'Sichuan'}
# {'2020': 1503413613,
#  '2021': 10991550205,
#  '2022': 27647598284,
#  '2023': 6289524021,
#  'Country/Region': 'China',
#  'Lat': '39.3054',
#  'Long': '117.323',
#  'Province/State': 'Tianjin'}
# {'2020': 1503413950,
#  '2021': 10991550570,
#  '2022': 27647778199,
#  '2023': 6289635321,
#  'Country/Region': 'China',
#  'Lat': '31.6927',
#  'Long': '88.0924',
#  'Province/State': 'Tibet'}
# {'2020': 1504618609,
#  '2021': 10995157663,
#  '2022': 27862095543,
#  '2023': 6393118745,
#  'Country/Region': 'China',
#  'Lat': '',
#  'Long': '',
#  'Province/State': 'Unknown'}
# {'2020': 1504776543,
#  '2021': 10995515451,
#  '2022': 27862568979,
#  '2023': 6393327466,
#  'Country/Region': 'China',
#  'Lat': '41.1129',
#  'Long': '85.2401',
#  'Province/State': 'Xinjiang'}
# {'2020': 1504841568,
#  '2021': 10995806168,
#  '2022': 27863489753,
#  '2023': 6393981470,
#  'Country/Region': 'China',
#  'Lat': '24.974',
#  'Long': '101.487',
#  'Province/State': 'Yunnan'}
# {'2020': 1505264150,
#  '2021': 10996323790,
#  '2022': 27864676239,
#  '2023': 6394751846,
#  'Country/Region': 'China',
#  'Lat': '29.1832',
#  'Long': '120.0934',
#  'Province/State': 'Zhejiang'}
# {'2020': 1660606786,
#  '2021': 12382464343,
#  '2022': 30106116237,
#  '2023': 6826657774,
#  'Country/Region': 'Colombia',
#  'Lat': '4.5709',
#  'Long': '-74.2973',
#  'Province/State': ''}
# {'2020': 1660704081,
#  '2021': 12383858512,
#  '2022': 30109142469,
#  '2023': 6827269281,
#  'Country/Region': 'Comoros',
#  'Lat': '-11.6455',
#  'Long': '43.3333',
#  'Province/State': ''}
# {'2020': 1661600779,
#  '2021': 12388504480,
#  '2022': 30118033179,
#  '2023': 6828985201,
#  'Country/Region': 'Congo (Brazzaville)',
#  'Lat': '-0.228',
#  'Long': '15.8277',
#  'Province/State': ''}
# {'2020': 1663838314,
#  '2021': 12403810840,
#  '2022': 30150796054,
#  '2023': 6835478297,
#  'Country/Region': 'Congo (Kinshasa)',
#  'Lat': '-4.0383',
#  'Long': '21.7587',
#  'Province/State': ''}
# {'2020': 1678347670,
#  '2021': 12539749500,
#  '2022': 30496805564,
#  '2023': 6916140028,
#  'Country/Region': 'Costa Rica',
#  'Lat': '9.7489',
#  'Long': '-83.7534',
#  'Province/State': ''}
# {'2020': 1682055284,
#  '2021': 12557418245,
#  '2022': 30527483088,
#  '2023': 6922127244,
#  'Country/Region': "Cote d'Ivoire",
#  'Lat': '7.54',
#  'Long': '-5.5471',
#  'Province/State': ''}
# {'2020': 1691977258,
#  '2021': 12693958984,
#  '2022': 30942536501,
#  '2023': 7008317763,
#  'Country/Region': 'Croatia',
#  'Lat': '45.1',
#  'Long': '15.2',
#  'Province/State': ''}
# {'2020': 1693178295,
#  '2021': 12844483700,
#  '2022': 31341359828,
#  '2023': 7083962220,
#  'Country/Region': 'Cuba',
#  'Lat': '21.521757',
#  'Long': '-77.781167',
#  'Province/State': ''}
# {'2020': 1694165424,
#  '2021': 12875539985,
#  '2022': 31519419336,
#  '2023': 7127666304,
#  'Country/Region': 'Cyprus',
#  'Lat': '35.1264',
#  'Long': '33.4299',
#  'Province/State': ''}
# {'2020': 1735114395,
#  '2021': 13464059229,
#  '2022': 33016674004,
#  '2023': 7440091052,
#  'Country/Region': 'Czechia',
#  'Lat': '49.8175',
#  'Long': '15.473',
#  'Province/State': ''}
# {'2020': 1735209461,
#  '2021': 13464548307,
#  '2022': 33028428941,
#  '2023': 7442447796,
#  'Country/Region': 'Denmark',
#  'Lat': '61.8926',
#  'Long': '-6.9118',
#  'Province/State': 'Faroe Islands'}
# {'2020': 1735213556,
#  '2021': 13464691853,
#  '2022': 33032633406,
#  '2023': 7443261824,
#  'Country/Region': 'Denmark',
#  'Lat': '71.7069',
#  'Long': '-42.6043',
#  'Province/State': 'Greenland'}
# {'2020': 1744427156,
#  '2021': 13580848336,
#  '2022': 34117892471,
#  '2023': 7674423929,
#  'Country/Region': 'Denmark',
#  'Lat': '56.2639',
#  'Long': '9.5018',
#  'Province/State': ''}
# {'2020': 1744655000,
#  '2021': 13581108216,
#  '2022': 34118152351,
#  '2023': 7674472345,
#  'Country/Region': 'Diamond Princess',
#  'Lat': '0.0',
#  'Long': '0.0',
#  'Province/State': ''}
# {'2020': 1745856333,
#  '2021': 13584984921,
#  '2022': 34123837328,
#  '2023': 7675539265,
#  'Country/Region': 'Djibouti',
#  'Lat': '11.8251',
#  'Long': '42.5903',
#  'Province/State': ''}
# {'2020': 1745865548,
#  '2021': 13585611718,
#  '2022': 34128756704,
#  '2023': 7676610945,
#  'Country/Region': 'Dominica',
#  'Lat': '15.415',
#  'Long': '-61.371',
#  'Province/State': ''}
# {'2020': 1767032273,
#  '2021': 13699256993,
#  '2022': 34349030981,
#  '2023': 7721488626,
#  'Country/Region': 'Dominican Republic',
#  'Lat': '18.7357',
#  'Long': '-70.1627',
#  'Province/State': ''}
# {'2020': 1795277863,
#  '2021': 13853346010,
#  '2022': 34679411592,
#  '2023': 7792923789,
#  'Country/Region': 'Ecuador',
#  'Lat': '-1.8312',
#  'Long': '-78.1834',
#  'Province/State': ''}
# {'2020': 1816287342,
#  '2021': 13949514747,
#  '2022': 34861768837,
#  '2023': 7827989201,
#  'Country/Region': 'Egypt',
#  'Lat': '26.820553',
#  'Long': '30.802498',
#  'Province/State': ''}
# {'2020': 1821699285,
#  '2021': 13980181881,
#  '2022': 34925535438,
#  '2023': 7841710581,
#  'Country/Region': 'El Salvador',
#  'Lat': '13.7942',
#  'Long': '-88.8965',
#  'Province/State': ''}
# {'2020': 1822639209,
#  '2021': 13983544287,
#  '2022': 34931511476,
#  '2023': 7842880387,
#  'Country/Region': 'Equatorial Guinea',
#  'Lat': '1.6508',
#  'Long': '10.2679',
#  'Province/State': ''}
# {'2020': 1822725585,
#  '2021': 13985404410,
#  '2022': 34935107527,
#  '2023': 7843573239,
#  'Country/Region': 'Eritrea',
#  'Lat': '15.1794',
#  'Long': '39.7823',
#  'Province/State': ''}
# {'2020': 1824083460,
#  '2021': 14033729571,
#  '2022': 35134688261,
#  '2023': 7885315723,
#  'Country/Region': 'Estonia',
#  'Lat': '58.5953',
#  'Long': '25.0136',
#  'Province/State': ''}
# {'2020': 1825015183,
#  '2021': 14044520720,
#  '2022': 35160904903,
#  '2023': 7890356858,
#  'Country/Region': 'Eswatini',
#  'Lat': '-26.5225',
#  'Long': '31.4659',
#  'Province/State': ''}
# {'2020': 1837847866,
#  '2021': 14143352898,
#  '2022': 35336528614,
#  '2023': 7924321641,
#  'Country/Region': 'Ethiopia',
#  'Lat': '9.145',
#  'Long': '40.4897',
#  'Province/State': ''}
# {'2020': 1837855516,
#  '2021': 14151446495,
#  '2022': 35360540970,
#  '2023': 7929002475,
#  'Country/Region': 'Fiji',
#  'Lat': '-17.7134',
#  'Long': '178.065',
#  'Province/State': ''}
# {'2020': 1841153033,
#  '2021': 14191875261,
#  '2022': 35746881356,
#  '2023': 8027990927,
#  'Country/Region': 'Finland',
#  'Lat': '61.92411',
#  'Long': '25.748151',
#  'Province/State': ''}
# {'2020': 1842979321,
#  '2021': 14202441116,
#  '2022': 35778148784,
#  '2023': 8034654499,
#  'Country/Region': 'France',
#  'Lat': '3.9339',
#  'Long': '-53.1258',
#  'Province/State': 'French Guiana'}
# {'2020': 1844001918,
#  '2021': 14212733110,
#  '2022': 35804057627,
#  '2023': 8039955677,
#  'Country/Region': 'France',
#  'Lat': '-17.6797',
#  'Long': '149.4068',
#  'Province/State': 'French Polynesia'}
# {'2020': 1844849966,
#  '2021': 14223015547,
#  '2022': 35862477974,
#  '2023': 8053641095,
#  'Country/Region': 'France',
#  'Lat': '16.265',
#  'Long': '-61.551',
#  'Province/State': 'Guadeloupe'}
# {'2020': 1845305071,
#  '2021': 14231224027,
#  '2022': 35926239222,
#  '2023': 8069154682,
#  'Country/Region': 'France',
#  'Lat': '14.6415',
#  'Long': '-61.0242',
#  'Province/State': 'Martinique'}
# {'2020': 1846152432,
#  '2021': 14237904532,
#  '2022': 35940166262,
#  '2023': 8072010781,
#  'Country/Region': 'France',
#  'Lat': '-12.8275',
#  'Long': '45.166244',
#  'Province/State': 'Mayotte'}
# {'2020': 1846159314,
#  '2021': 14239051976,
#  '2022': 35962669152,
#  '2023': 8077445462,
#  'Country/Region': 'France',
#  'Lat': '-20.904305',
#  'Long': '165.618042',
#  'Province/State': 'New Caledonia'}
# {'2020': 1846960718,
#  '2021': 14251611659,
#  '2022': 36104834295,
#  '2023': 8110963519,
#  'Country/Region': 'France',
#  'Lat': '-21.1151',
#  'Long': '55.5364',
#  'Province/State': 'Reunion'}
# {'2020': 1846973440,
#  '2021': 14252025840,
#  '2022': 36106513805,
#  '2023': 8111332322,
#  'Country/Region': 'France',
#  'Lat': '17.9',
#  'Long': '-62.8333',
#  'Province/State': 'Saint Barthelemy'}
# {'2020': 1846975510,
#  '2021': 14252037845,
#  '2022': 36107428314,
#  '2023': 8111564968,
#  'Country/Region': 'France',
#  'Lat': '46.8852',
#  'Long': '-56.3159',
#  'Province/State': 'Saint Pierre and Miquelon'}
# {'2020': 1847054464,
#  '2021': 14252977461,
#  '2022': 36111369504,
#  '2023': 8112396651,
#  'Country/Region': 'France',
#  'Lat': '18.0708',
#  'Long': '-63.0501',
#  'Province/State': 'St Martin'}
# {'2020': 1847054637,
#  '2021': 14253108551,
#  '2022': 36111794100,
#  '2023': 8112629663,
#  'Country/Region': 'France',
#  'Lat': '-14.2938',
#  'Long': '-178.1165',
#  'Province/State': 'Wallis and Futuna'}
# {'2020': 2050118979,
#  '2021': 16335662036,
#  '2022': 46798541537,
#  '2023': 10729489911,
#  'Country/Region': 'France',
#  'Lat': '46.2276',
#  'Long': '2.2137',
#  'Province/State': ''}
# {'2020': 2051829690,
#  '2021': 16344697682,
#  '2022': 46816032526,
#  '2023': 10732820590,
#  'Country/Region': 'Gabon',
#  'Lat': '-0.8037',
#  'Long': '11.6094',
#  'Province/State': ''}
# {'2020': 2052335668,
#  '2021': 16347338459,
#  '2022': 46820455491,
#  '2023': 10733676474,
#  'Country/Region': 'Gambia',
#  'Lat': '13.4432',
#  'Long': '-15.3101',
#  'Province/State': ''}
# {'2020': 2061608286,
#  '2021': 16517206025,
#  '2022': 47416489973,
#  '2023': 10857233159,
#  'Country/Region': 'Georgia',
#  'Lat': '42.3154',
#  'Long': '43.3569',
#  'Province/State': ''}
# {'2020': 2176181082,
#  '2021': 17891429905,
#  '2022': 57040827487,
#  '2023': 13430142689,
#  'Country/Region': 'Germany',
#  'Lat': '51.165691',
#  'Long': '10.451526',
#  'Province/State': ''}
# {'2020': 2184851039,
#  '2021': 17928870984,
#  '2022': 57100861661,
#  '2023': 13441779332,
#  'Country/Region': 'Ghana',
#  'Lat': '7.9465',
#  'Long': '-1.0232',
#  'Province/State': ''}
# {'2020': 2192827133,
#  '2021': 18107040320,
#  '2022': 58502102081,
#  '2023': 13819076448,
#  'Country/Region': 'Greece',
#  'Lat': '39.0742',
#  'Long': '21.8243',
#  'Province/State': ''}
# {'2020': 2192835439,
#  '2021': 18107707425,
#  '2022': 58508231838,
#  '2023': 13820414556,
#  'Country/Region': 'Grenada',
#  'Lat': '12.1165',
#  'Long': '-61.679',
#  'Province/State': ''}
# {'2020': 2209344521,
#  '2021': 18239280965,
#  '2022': 58855450226,
#  '2023': 13903813977,
#  'Country/Region': 'Guatemala',
#  'Lat': '15.7835',
#  'Long': '-90.2308',
#  'Province/State': ''}
# {'2020': 2211489048,
#  '2021': 18248101977,
#  '2022': 58868966027,
#  '2023': 13906414340,
#  'Country/Region': 'Guinea',
#  'Lat': '9.9456',
#  'Long': '-9.6966',
#  'Province/State': ''}
# {'2020': 2211976031,
#  '2021': 18249757337,
#  '2022': 58872004433,
#  '2023': 13907022949,
#  'Country/Region': 'Guinea-Bissau',
#  'Lat': '11.8037',
#  'Long': '-15.1804',
#  'Province/State': ''}
# {'2020': 2212524739,
#  '2021': 18257492702,
#  '2022': 58896176822,
#  '2023': 13911976994,
#  'Country/Region': 'Guyana',
#  'Lat': '4.860416',
#  'Long': '-58.93018',
#  'Province/State': ''}
# {'2020': 2214220644,
#  '2021': 18264055035,
#  '2022': 58907773779,
#  '2023': 13914292625,
#  'Country/Region': 'Haiti',
#  'Lat': '18.9712',
#  'Long': '-72.2852',
#  'Province/State': ''}
# {'2020': 2214225073,
#  '2021': 18264064890,
#  '2022': 58907784330,
#  '2023': 13914294597,
#  'Country/Region': 'Holy See',
#  'Lat': '41.9029',
#  'Long': '12.4534',
#  'Province/State': ''}
# {'2020': 2228637157,
#  '2021': 18362530556,
#  '2022': 59065588588,
#  '2023': 13946283272,
#  'Country/Region': 'Honduras',
#  'Lat': '15.2',
#  'Long': '-86.2419',
#  'Province/State': ''}
# {'2020': 2244198274,
#  '2021': 18638732557,
#  '2022': 59767659683,
#  '2023': 14095361110,
#  'Country/Region': 'Hungary',
#  'Lat': '47.1625',
#  'Long': '19.5033',
#  'Province/State': ''}
# {'2020': 2245006132,
#  '2021': 18642223730,
#  '2022': 59831527494,
#  '2023': 14109553556,
#  'Country/Region': 'Iceland',
#  'Lat': '64.9631',
#  'Long': '-19.0208',
#  'Province/State': ''}
# {'2020': 3329286370,
#  '2021': 27857299291,
#  '2022': 75624733402,
#  '2023': 17148111543,
#  'Country/Region': 'India',
#  'Lat': '20.593684',
#  'Long': '78.96288',
#  'Province/State': ''}
# {'2020': 3389860095,
#  '2021': 28845119924,
#  '2022': 77811076209,
#  '2023': 17605781076,
#  'Country/Region': 'Indonesia',
#  'Lat': '-0.7893',
#  'Long': '113.9213',
#  'Province/State': ''}
# {'2020': 3507765906,
#  '2021': 30184078341,
#  '2022': 80452204459,
#  '2023': 18120211047,
#  'Country/Region': 'Iran',
#  'Lat': '32.427908',
#  'Long': '53.688046',
#  'Province/State': ''}
# {'2020': 3572384685,
#  '2021': 30696796194,
#  '2022': 81316287822,
#  '2023': 18287867514,
#  'Country/Region': 'Iraq',
#  'Lat': '33.223191',
#  'Long': '43.679291',
#  'Province/State': ''}
# {'2020': 3582849472,
#  '2021': 30816243401,
#  '2022': 81871858871,
#  '2023': 18403462433,
#  'Country/Region': 'Ireland',
#  'Lat': '53.1424',
#  'Long': '-7.6921',
#  'Province/State': ''}
# {'2020': 3624372418,
#  '2021': 31169669701,
#  '2022': 83373395775,
#  '2023': 18728945637,
#  'Country/Region': 'Israel',
#  'Lat': '31.046051',
#  'Long': '34.851612',
#  'Province/State': ''}
# {'2020': 3775673177,
#  '2021': 32659732878,
#  '2022': 90084740028,
#  '2023': 20459399126,
#  'Country/Region': 'Italy',
#  'Lat': '41.87194',
#  'Long': '12.56738',
#  'Province/State': ''}
# {'2020': 3776823238,
#  '2021': 32679931154,
#  '2022': 90135548274,
#  '2023': 20469841714,
#  'Country/Region': 'Jamaica',
#  'Lat': '18.1096',
#  'Long': '-77.2975',
#  'Province/State': ''}
# {'2020': 3795290210,
#  '2021': 33046648913,
#  '2022': 94895721204,
#  '2023': 22662695684,
#  'Country/Region': 'Japan',
#  'Lat': '36.204824',
#  'Long': '138.252924',
#  'Province/State': ''}
# {'2020': 3809381130,
#  '2021': 33303678004,
#  '2022': 95497035783,
#  '2023': 22781491480,
#  'Country/Region': 'Jordan',
#  'Lat': '31.24',
#  'Long': '36.51',
#  'Province/State': ''}
# {'2020': 3835090645,
#  '2021': 33526149801,
#  '2022': 96012143755,
#  '2023': 22883154529,
#  'Country/Region': 'Kazakhstan',
#  'Lat': '48.0196',
#  'Long': '66.9237',
#  'Province/State': ''}
# {'2020': 3843976141,
#  '2021': 33594480276,
#  '2022': 96132933850,
#  '2023': 22906464299,
#  'Country/Region': 'Kenya',
#  'Lat': '-0.0236',
#  'Long': '37.9062',
#  'Province/State': ''}
# {'2020': 3843976141,
#  '2021': 33594480729,
#  '2022': 96134004521,
#  '2023': 22906789715,
#  'Country/Region': 'Kiribati',
#  'Lat': '-3.3704',
#  'Long': '-168.734',
#  'Province/State': ''}
# {'2020': 3843976141,
#  '2021': 33594480729,
#  '2022': 96134004753,
#  '2023': 22906789783,
#  'Country/Region': 'Korea, North',
#  'Lat': '40.3399',
#  'Long': '127.5101',
#  'Province/State': ''}
# {'2020': 3849991762,
#  '2021': 33674794419,
#  '2022': 102465981332,
#  '2023': 24956372861,
#  'Country/Region': 'Korea, South',
#  'Lat': '35.907757',
#  'Long': '127.766922',
#  'Province/State': ''}
# {'2020': 3853900802,
#  '2021': 33716818526,
#  '2022': 102554198410,
#  '2023': 24974914456,
#  'Country/Region': 'Kosovo',
#  'Lat': '42.602636',
#  'Long': '20.902977',
#  'Province/State': ''}
# {'2020': 3874740745,
#  '2021': 33834653762,
#  '2022': 102783659956,
#  '2023': 25019997511,
#  'Country/Region': 'Kuwait',
#  'Lat': '29.31166',
#  'Long': '47.481766',
#  'Province/State': ''}
# {'2020': 3884118274,
#  '2021': 33883471130,
#  '2022': 102857450869,
#  '2023': 25034046776,
#  'Country/Region': 'Kyrgyzstan',
#  'Lat': '41.20438',
#  'Long': '74.766098',
#  'Province/State': ''}
# {'2020': 3884124748,
#  '2021': 33890173577,
#  '2022': 102928167064,
#  '2023': 25048868315,
#  'Country/Region': 'Laos',
#  'Lat': '19.85627',
#  'Long': '102.495496',
#  'Province/State': ''}
# {'2020': 3885643310,
#  '2021': 33942537762,
#  '2022': 103219973909,
#  '2023': 25115193059,
#  'Country/Region': 'Latvia',
#  'Lat': '56.8796',
#  'Long': '24.6032',
#  'Province/State': ''}
# {'2020': 3896702779,
#  '2021': 34135203747,
#  '2022': 103628477215,
#  '2023': 25198729898,
#  'Country/Region': 'Lebanon',
#  'Lat': '33.8547',
#  'Long': '35.8623',
#  'Province/State': ''}
# {'2020': 3896973593,
#  '2021': 34140316735,
#  '2022': 103640722967,
#  '2023': 25201095018,
#  'Country/Region': 'Lesotho',
#  'Lat': '-29.61',
#  'Long': '28.2336',
#  'Province/State': ''}
# {'2020': 3897248804,
#  '2021': 34141744739,
#  '2022': 103643496546,
#  '2023': 25201643083,
#  'Country/Region': 'Liberia',
#  'Lat': '6.428055',
#  'Long': '-9.429499',
#  'Province/State': ''}
# {'2020': 3904856948,
#  '2021': 34228574651,
#  '2022': 103823420101,
#  '2023': 25236130228,
#  'Country/Region': 'Libya',
#  'Lat': '26.3351',
#  'Long': '17.228331',
#  'Province/State': ''}
# {'2020': 3904965732,
#  '2021': 34229790588,
#  '2022': 103829613930,
#  '2023': 25237582838,
#  'Country/Region': 'Liechtenstein',
#  'Lat': '47.14',
#  'Long': '9.55',
#  'Province/State': ''}
# {'2020': 3909915674,
#  '2021': 34337780715,
#  '2022': 104236689371,
#  '2023': 25325837516,
#  'Country/Region': 'Lithuania',
#  'Lat': '55.1694',
#  'Long': '23.8813',
#  'Province/State': ''}
# {'2020': 3913344530,
#  '2021': 34363632260,
#  '2022': 104327667446,
#  '2023': 25347252353,
#  'Country/Region': 'Luxembourg',
#  'Lat': '49.8153',
#  'Long': '6.1296',
#  'Province/State': ''}
# {'2020': 3913347013,
#  '2021': 34363635545,
#  '2022': 104327670731,
#  '2023': 25347252965,
#  'Country/Region': 'MS Zaandam',
#  'Lat': '0.0',
#  'Long': '0.0',
#  'Province/State': ''}
# {'2020': 3916072624,
#  '2021': 34376869531,
#  '2022': 104351242758,
#  '2023': 25351864830,
#  'Country/Region': 'Madagascar',
#  'Lat': '-18.766947',
#  'Long': '46.869107',
#  'Province/State': ''}
# {'2020': 3917055203,
#  '2021': 34392995097,
#  '2022': 104382782718,
#  '2023': 25357883111,
#  'Country/Region': 'Malawi',
#  'Lat': '-13.2543',
#  'Long': '34.3015',
#  'Province/State': ''}
# {'2020': 3923361363,
#  '2021': 34828824094,
#  '2022': 105972298886,
#  '2023': 25700406864,
#  'Country/Region': 'Malaysia',
#  'Lat': '4.210484',
#  'Long': '101.975766',
#  'Province/State': ''}
# {'2020': 3925140320,
#  '2021': 34850362754,
#  '2022': 106035878124,
#  '2023': 25713035525,
#  'Country/Region': 'Maldives',
#  'Lat': '3.2028',
#  'Long': '73.2207',
#  'Province/State': ''}
# {'2020': 3925880363,
#  '2021': 34855288638,
#  '2022': 106047243499,
#  '2023': 25715269529,
#  'Country/Region': 'Mali',
#  'Lat': '17.570692',
#  'Long': '-3.996166',
#  'Province/State': ''}
# {'2020': 3926800422,
#  '2021': 34866738969,
#  '2022': 106082883131,
#  '2023': 25723229690,
#  'Country/Region': 'Malta',
#  'Lat': '35.9375',
#  'Long': '14.3754',
#  'Province/State': ''}
# {'2020': 3926800630,
#  '2021': 34866740429,
#  '2022': 106084957183,
#  '2023': 25724289111,
#  'Country/Region': 'Marshall Islands',
#  'Lat': '7.1315',
#  'Long': '171.1845',
#  'Province/State': ''}
# {'2020': 3928306083,
#  '2021': 34876199878,
#  '2022': 106106974564,
#  '2023': 25728614630,
#  'Country/Region': 'Mauritania',
#  'Lat': '21.0079',
#  'Long': '-10.9408',
#  'Province/State': ''}
# {'2020': 3928411297,
#  '2021': 34880879546,
#  '2022': 106187175320,
#  '2023': 25748618929,
#  'Country/Region': 'Mauritius',
#  'Lat': '-20.348404',
#  'Long': '57.552152',
#  'Province/State': ''}
# {'2020': 4077433510,
#  '2021': 35909115904,
#  '2022': 108452591339,
#  '2023': 26250052353,
#  'Country/Region': 'Mexico',
#  'Lat': '23.6345',
#  'Long': '-102.5528',
#  'Province/State': ''}
# {'2020': 4077433510,
#  '2021': 35909116249,
#  '2022': 108455100659,
#  '2023': 26251615866,
#  'Country/Region': 'Micronesia',
#  'Lat': '7.4256',
#  'Long': '150.5508',
#  'Province/State': ''}
# {'2020': 4089717745,
#  '2021': 36004353205,
#  '2022': 108649435285,
#  '2023': 26292435808,
#  'Country/Region': 'Moldova',
#  'Lat': '47.4116',
#  'Long': '28.3699',
#  'Province/State': ''}
# {'2020': 4089786203,
#  '2021': 36005350991,
#  '2022': 108653997264,
#  '2023': 26293528135,
#  'Country/Region': 'Monaco',
#  'Lat': '43.7333',
#  'Long': '7.4167',
#  'Province/State': ''}
# {'2020': 4089876792,
#  '2021': 36084558598,
#  '2022': 108993883102,
#  '2023': 26362060794,
#  'Country/Region': 'Mongolia',
#  'Lat': '46.8625',
#  'Long': '103.8467',
#  'Province/State': ''}
# {'2020': 4092907167,
#  '2021': 36123720790,
#  '2022': 109085557298,
#  '2023': 26381552785,
#  'Country/Region': 'Montenegro',
#  'Lat': '42.708678',
#  'Long': '19.37439',
#  'Province/State': ''}
# {'2020': 4124636629,
#  '2021': 36368602484,
#  '2022': 109525390879,
#  '2023': 26468063658,
#  'Country/Region': 'Morocco',
#  'Lat': '31.7917',
#  'Long': '-7.0926',
#  'Province/State': ''}
# {'2020': 4126268068,
#  '2021': 36405250223,
#  '2022': 109608208148,
#  '2023': 26483852683,
#  'Country/Region': 'Mozambique',
#  'Lat': '-18.665695',
#  'Long': '35.529562',
#  'Province/State': ''}
# {'2020': 4128079956,
#  '2021': 36436581510,
#  '2022': 109668233056,
#  '2023': 26495462530,
#  'Country/Region': 'Namibia',
#  'Lat': '-22.9576',
#  'Long': '18.4904',
#  'Province/State': ''}
# {'2020': 4128079956,
#  '2021': 36436581510,
#  '2022': 109669088502,
#  '2023': 26495791996,
#  'Country/Region': 'Nauru',
#  'Lat': '-0.5228',
#  'Long': '166.9315',
#  'Province/State': ''}
# {'2020': 4149321686,
#  '2021': 36643838529,
#  '2022': 110026052231,
#  '2023': 26563866422,
#  'Country/Region': 'Nepal',
#  'Lat': '28.1667',
#  'Long': '84.25',
#  'Province/State': ''}
# {'2020': 4149893523,
#  '2021': 36648199828,
#  '2022': 110040175138,
#  '2023': 26566856632,
#  'Country/Region': 'Netherlands',
#  'Lat': '12.5211',
#  'Long': '-69.9683',
#  'Province/State': 'Aruba'}
# {'2020': 4149910601,
#  '2021': 36648737864,
#  '2022': 110043756504,
#  '2023': 26567657962,
#  'Country/Region': 'Netherlands',
#  'Lat': '12.1784',
#  'Long': '-68.2385',
#  'Province/State': 'Bonaire, Sint Eustatius and Saba'}
# {'2020': 4150098975,
#  '2021': 36653201126,
#  '2022': 110059298152,
#  '2023': 26570785010,
#  'Country/Region': 'Netherlands',
#  'Lat': '12.1696',
#  'Long': '-68.99',
#  'Province/State': 'Curacao'}
# {'2020': 4150225141,
#  '2021': 36654309931,
#  '2022': 110063028961,
#  '2023': 26571533750,
#  'Country/Region': 'Netherlands',
#  'Lat': '18.0425',
#  'Long': '-63.0548',
#  'Province/State': 'Sint Maarten'}
# {'2020': 4201483698,
#  '2021': 37289040275,
#  '2022': 112847143441,
#  '2023': 27155274920,
#  'Country/Region': 'Netherlands',
#  'Lat': '52.1326',
#  'Long': '5.2913',
#  'Province/State': ''}
# {'2020': 4201483698,
#  '2021': 37289040529,
#  '2022': 112848771787,
#  '2023': 27155747287,
#  'Country/Region': 'New Zealand',
#  'Lat': '-21.2367',
#  'Long': '-159.7777',
#  'Province/State': 'Cook Islands'}
# {'2020': 4201483698,
#  '2021': 37289040529,
#  '2022': 112848791476,
#  '2023': 27155796976,
#  'Country/Region': 'New Zealand',
#  'Lat': '-19.0544',
#  'Long': '-169.8672',
#  'Province/State': 'Niue'}
# {'2020': 4201955100,
#  '2021': 37290637911,
#  '2022': 113286179181,
#  '2023': 27303953651,
#  'Country/Region': 'New Zealand',
#  'Lat': '-40.9006',
#  'Long': '174.886',
#  'Province/State': ''}
# {'2020': 4202730937,
#  '2021': 37293583819,
#  '2022': 113291510240,
#  '2023': 27305012124,
#  'Country/Region': 'Nicaragua',
#  'Lat': '12.865416',
#  'Long': '-85.207229',
#  'Province/State': ''}
# {'2020': 4203062280,
#  '2021': 37295617515,
#  '2022': 113294813064,
#  '2023': 27305658224,
#  'Country/Region': 'Niger',
#  'Lat': '17.607789',
#  'Long': '8.081666',
#  'Province/State': ''}
# {'2020': 4214294391,
#  '2021': 37359911333,
#  '2022': 113389466447,
#  '2023': 27323779036,
#  'Country/Region': 'Nigeria',
#  'Lat': '9.082',
#  'Long': '8.6753',
#  'Province/State': ''}
# {'2020': 4220115518,
#  '2021': 37417420240,
#  '2022': 113504976370,
#  '2023': 27347337461,
#  'Country/Region': 'North Macedonia',
#  'Lat': '41.6086',
#  'Long': '21.7453',
#  'Province/State': ''}
# {'2020': 4224544896,
#  '2021': 37471940729,
#  '2022': 113992423765,
#  '2023': 27447831140,
#  'Country/Region': 'Norway',
#  'Lat': '60.472',
#  'Long': '8.4689',
#  'Province/State': ''}
# {'2020': 4243598865,
#  '2021': 37558636659,
#  '2022': 114132981338,
#  '2023': 27474985117,
#  'Country/Region': 'Oman',
#  'Lat': '21.512583',
#  'Long': '55.923255',
#  'Province/State': ''}
# {'2020': 4310329985,
#  '2021': 37906592089,
#  '2022': 114690869439,
#  '2023': 27582182961,
#  'Country/Region': 'Pakistan',
#  'Lat': '30.3753',
#  'Long': '69.3451',
#  'Province/State': ''}
# {'2020': 4310329985,
#  '2021': 37906592920,
#  '2022': 114692535954,
#  '2023': 27582589878,
#  'Country/Region': 'Palau',
#  'Lat': '7.515',
#  'Long': '134.5825',
#  'Province/State': ''}
# {'2020': 4333101251,
#  '2021': 38054345278,
#  '2022': 115010491626,
#  '2023': 27652578391,
#  'Country/Region': 'Panama',
#  'Lat': '8.538',
#  'Long': '-80.7821',
#  'Province/State': ''}
# {'2020': 4333185777,
#  '2021': 38060202126,
#  '2022': 115026368540,
#  '2023': 27655756104,
#  'Country/Region': 'Papua New Guinea',
#  'Lat': '-6.314993',
#  'Long': '143.95555',
#  'Province/State': ''}
# {'2020': 4341376268,
#  '2021': 38186935480,
#  '2022': 115271277914,
#  '2023': 27710451434,
#  'Country/Region': 'Paraguay',
#  'Lat': '-23.4425',
#  'Long': '-58.4438',
#  'Province/State': ''}
# {'2020': 4486007091,
#  '2021': 38867939765,
#  '2022': 116640448815,
#  '2023': 28015058443,
#  'Country/Region': 'Peru',
#  'Lat': '-9.19',
#  'Long': '-75.0152',
#  'Province/State': ''}
# {'2020': 4539538924,
#  '2021': 39447124120,
#  '2022': 118012414699,
#  '2023': 28292013248,
#  'Country/Region': 'Philippines',
#  'Lat': '12.879721',
#  'Long': '121.774017',
#  'Province/State': ''}
# {'2020': 4609321536,
#  '2021': 40424937970,
#  '2022': 120173925030,
#  '2023': 28726586479,
#  'Country/Region': 'Poland',
#  'Lat': '51.9194',
#  'Long': '19.1451',
#  'Province/State': ''}
# {'2020': 4637850796,
#  '2021': 40762302201,
#  '2022': 121835460847,
#  '2023': 29104897213,
#  'Country/Region': 'Portugal',
#  'Lat': '39.3999',
#  'Long': '-8.2245',
#  'Province/State': ''}
# {'2020': 4664367198,
#  '2021': 40838974654,
#  '2022': 121981171998,
#  '2023': 29138390165,
#  'Country/Region': 'Qatar',
#  'Lat': '25.3548',
#  'Long': '51.1839',
#  'Province/State': ''}
# {'2020': 4706193053,
#  '2021': 41258987752,
#  '2022': 123054002315,
#  '2023': 29364592087,
#  'Country/Region': 'Romania',
#  'Lat': '45.9432',
#  'Long': '24.9668',
#  'Province/State': ''}
# {'2020': 5000296827,
#  '2021': 43478571617,
#  '2022': 129641961950,
#  '2023': 30841514655,
#  'Country/Region': 'Russia',
#  'Lat': '61.52401',
#  'Long': '105.318756',
#  'Province/State': ''}
# {'2020': 5001132592,
#  '2021': 43498707487,
#  '2022': 129689641568,
#  '2023': 30850565887,
#  'Country/Region': 'Rwanda',
#  'Lat': '-1.9403',
#  'Long': '29.8739',
#  'Province/State': ''}
# {'2020': 5001137533,
#  '2021': 43499052617,
#  '2022': 129691824663,
#  '2023': 30851013851,
#  'Country/Region': 'Saint Kitts and Nevis',
#  'Lat': '17.357822',
#  'Long': '-62.782998',
#  'Province/State': ''}
# {'2020': 5001156822,
#  '2021': 43501548743,
#  '2022': 129701264157,
#  '2023': 30853042933,
#  'Country/Region': 'Saint Lucia',
#  'Lat': '13.9094',
#  'Long': '-60.9789',
#  'Province/State': ''}
# {'2020': 5001171038,
#  '2021': 43502528131,
#  '2022': 129704480184,
#  '2023': 30853694177,
#  'Country/Region': 'Saint Vincent and the Grenadines',
#  'Lat': '12.9843',
#  'Long': '-61.2872',
#  'Province/State': ''}
# {'2020': 5001171117,
#  '2021': 43502529181,
#  '2022': 129708340858,
#  '2023': 30854797607,
#  'Country/Region': 'Samoa',
#  'Lat': '-13.759',
#  'Long': '-172.1046',
#  'Province/State': ''}
# {'2020': 5001418607,
#  '2021': 43504334235,
#  '2022': 129714881355,
#  '2023': 30856390052,
#  'Country/Region': 'San Marino',
#  'Lat': '43.9424',
#  'Long': '12.4578',
#  'Province/State': ''}
# {'2020': 5001612696,
#  '2021': 43505269492,
#  '2022': 129717078260,
#  '2023': 30856817079,
#  'Country/Region': 'Sao Tome and Principe',
#  'Lat': '0.1864',
#  'Long': '6.6131',
#  'Province/State': ''}
# {'2020': 5066444227,
#  '2021': 43677808187,
#  '2022': 129999626099,
#  '2023': 30913140086,
#  'Country/Region': 'Saudi Arabia',
#  'Lat': '23.885942',
#  'Long': '45.079162',
#  'Province/State': ''}
# {'2020': 5069247864,
#  '2021': 43696992639,
#  '2022': 130031259502,
#  '2023': 30919185714,
#  'Country/Region': 'Senegal',
#  'Lat': '14.4974',
#  'Long': '-14.4524',
#  'Province/State': ''}
# {'2020': 5085153149,
#  '2021': 43978473655,
#  '2022': 130795289265,
#  '2023': 31087404330,
#  'Country/Region': 'Serbia',
#  'Lat': '44.0165',
#  'Long': '21.0059',
#  'Province/State': ''}
# {'2020': 5085180978,
#  '2021': 43983347560,
#  '2022': 130811221820,
#  '2023': 31090840250,
#  'Country/Region': 'Seychelles',
#  'Lat': '-4.6796',
#  'Long': '55.492',
#  'Province/State': ''}
# {'2020': 5085628559,
#  '2021': 43985225406,
#  '2022': 130814030269,
#  '2023': 31091367930,
#  'Country/Region': 'Sierra Leone',
#  'Lat': '8.460555',
#  'Long': '-11.779889',
#  'Province/State': ''}
# {'2020': 5098127201,
#  '2021': 44022701169,
#  '2022': 131336769116,
#  '2023': 31242204212,
#  'Country/Region': 'Singapore',
#  'Lat': '1.2833',
#  'Long': '103.8333',
#  'Province/State': ''}
# {'2020': 5108201232,
#  '2021': 44306481917,
#  '2022': 132216330712,
#  '2023': 31423198876,
#  'Country/Region': 'Slovakia',
#  'Lat': '48.669',
#  'Long': '19.699',
#  'Province/State': ''}
# {'2020': 5113817969,
#  '2021': 44403971539,
#  '2022': 132594647041,
#  '2023': 31513076724,
#  'Country/Region': 'Slovenia',
#  'Lat': '46.1512',
#  'Long': '14.9955',
#  'Province/State': ''}
# {'2020': 5113819041,
#  '2021': 44403978621,
#  '2022': 132600737995,
#  '2023': 31514747824,
#  'Country/Region': 'Solomon Islands',
#  'Lat': '-9.6457',
#  'Long': '160.1562',
#  'Province/State': ''}
# {'2020': 5114633670,
#  '2021': 44409450544,
#  '2022': 132610457852,
#  '2023': 31516605428,
#  'Country/Region': 'Somalia',
#  'Lat': '5.152149',
#  'Long': '46.199616',
#  'Province/State': ''}
# {'2020': 5237429816,
#  '2021': 45204938601,
#  '2022': 134029403831,
#  '2023': 31792474735,
#  'Country/Region': 'South Africa',
#  'Lat': '-30.5595',
#  'Long': '22.9375',
#  'Province/State': ''}
# {'2020': 5237991997,
#  '2021': 45208683347,
#  '2022': 134035815998,
#  '2023': 31793723759,
#  'Country/Region': 'South Sudan',
#  'Lat': '6.877',
#  'Long': '31.307',
#  'Province/State': ''}
# {'2020': 5424510143,
#  '2021': 46688971320,
#  '2022': 138506388139,
#  '2023': 32727620647,
#  'Country/Region': 'Spain',
#  'Lat': '40.463667',
#  'Long': '-3.74922',
#  'Province/State': ''}
# {'2020': 5426644222,
#  '2021': 46795433260,
#  '2022': 138746454316,
#  '2023': 32773315950,
#  'Country/Region': 'Sri Lanka',
#  'Lat': '7.873054',
#  'Long': '80.771797',
#  'Province/State': ''}
# {'2020': 5429629829,
#  '2021': 46808545103,
#  '2022': 138768958833,
#  '2023': 32777650964,
#  'Country/Region': 'Sudan',
#  'Lat': '12.8628',
#  'Long': '30.2176',
#  'Province/State': ''}
# {'2020': 5429629829,
#  '2021': 46808669246,
#  '2022': 138769274558,
#  '2023': 32777709784,
#  'Country/Region': 'Summer Olympics 2020',
#  'Lat': '35.6491',
#  'Long': '139.7737',
#  'Province/State': ''}
# {'2020': 5430386195,
#  '2021': 46817813202,
#  '2022': 138798069548,
#  '2023': 32783296756,
#  'Country/Region': 'Suriname',
#  'Lat': '3.9193',
#  'Long': '-56.0278',
#  'Province/State': ''}
# {'2020': 5460289136,
#  '2021': 47177675034,
#  '2022': 139696242087,
#  '2023': 32966373506,
#  'Country/Region': 'Sweden',
#  'Lat': '60.128161',
#  'Long': '18.643501',
#  'Province/State': ''}
# {'2020': 5489281154,
#  '2021': 47446902884,
#  '2022': 141011270876,
#  '2023': 33266105300,
#  'Country/Region': 'Switzerland',
#  'Lat': '46.8182',
#  'Long': '8.2275',
#  'Province/State': ''}
# {'2020': 5490122113,
#  '2021': 47457018869,
#  '2022': 141031616571,
#  '2023': 33270011878,
#  'Country/Region': 'Syria',
#  'Lat': '34.802075',
#  'Long': '38.996815',
#  'Province/State': ''}
# {'2020': 5490267315,
#  '2021': 47460588422,
#  '2022': 142343746450,
#  '2023': 33920547504,
#  'Country/Region': 'Taiwan*',
#  'Lat': '23.7',
#  'Long': '121.0',
#  'Province/State': ''}
# {'2020': 5492266285,
#  '2021': 47466165837,
#  '2022': 142350229878,
#  '2023': 33921756952,
#  'Country/Region': 'Tajikistan',
#  'Lat': '38.861',
#  'Long': '71.2761',
#  'Province/State': ''}
# {'2020': 5492395525,
#  '2021': 47468970669,
#  '2022': 142363569910,
#  '2023': 33924656515,
#  'Country/Region': 'Tanzania',
#  'Lat': '-6.369028',
#  'Long': '34.888822',
#  'Province/State': ''}
# {'2020': 5493365233,
#  '2021': 47748314538,
#  '2022': 143857501612,
#  '2023': 34246069420,
#  'Country/Region': 'Thailand',
#  'Lat': '15.870032',
#  'Long': '100.992541',
#  'Province/State': ''}
# {'2020': 5493372263,
#  '2021': 47751853687,
#  '2022': 143865782647,
#  '2023': 34247661427,
#  'Country/Region': 'Timor-Leste',
#  'Lat': '-8.874217',
#  'Long': '125.727539',
#  'Province/State': ''}
# {'2020': 5493753992,
#  '2021': 47757766533,
#  '2022': 143879543771,
#  '2023': 34250337947,
#  'Country/Region': 'Togo',
#  'Lat': '8.6195',
#  'Long': '0.8248',
#  'Province/State': ''}
# {'2020': 5493753992,
#  '2021': 47757766597,
#  '2022': 143883384166,
#  '2023': 34251472716,
#  'Country/Region': 'Tonga',
#  'Lat': '-21.179',
#  'Long': '-175.1982',
#  'Province/State': ''}
# {'2020': 5494450076,
#  '2021': 47770098372,
#  '2022': 143941221389,
#  '2023': 34264246200,
#  'Country/Region': 'Trinidad and Tobago',
#  'Lat': '10.6918',
#  'Long': '-61.2225',
#  'Province/State': ''}
# {'2020': 5502099659,
#  '2021': 47941360774,
#  '2022': 144328524800,
#  '2023': 34342438087,
#  'Country/Region': 'Tunisia',
#  'Lat': '33.886917',
#  'Long': '9.537499',
#  'Province/State': ''}
# {'2020': 5612880506,
#  '2021': 49955682389,
#  '2022': 149885259941,
#  '2023': 35501343183,
#  'Country/Region': 'Turkey',
#  'Lat': '38.9637',
#  'Long': '35.2433',
#  'Province/State': ''}
# {'2020': 5612880506,
#  '2021': 49955682389,
#  '2022': 149885392102,
#  '2023': 35501533923,
#  'Country/Region': 'Tuvalu',
#  'Lat': '-7.1095',
#  'Long': '177.6493',
#  'Province/State': ''}
# {'2020': 7341907336,
#  '2021': 63223971321,
#  '2022': 181732112700,
#  '2023': 42470681969,
#  'Country/Region': 'US',
#  'Lat': '40.0',
#  'Long': '-100.0',
#  'Province/State': ''}
# {'2020': 7343877795,
#  '2021': 63253373307,
#  '2022': 181792744542,
#  '2023': 42482265608,
#  'Country/Region': 'Uganda',
#  'Lat': '1.373333',
#  'Long': '32.290275',
#  'Province/State': ''}
# {'2020': 7410786295,
#  '2021': 64091897020,
#  '2022': 183691458527,
#  '2023': 42868733260,
# ...
# {'2020': 12511929888,
#  '2021': 86693369831,
#  '2022': 197801368641,
#  '2023': 45864143123,
#  'Country/Region': 'Nicaragua',
#  'Lat': '12.865416',
#  'Long': '-85.207229',
#  'Province/State': ''}
# {'2020': 12511947194,
#  '2021': 86693441677,
#  '2022': 197801481310,
#  '2023': 45864164539,
#  'Country/Region': 'Niger',
#  'Lat': '17.607789',
#  'Long': '8.081666',
#  'Province/State': ''}
# {'2020': 12512159874,
#  '2021': 86694269239,
#  '2022': 197802628649,
#  '2023': 45864379079,
#  'Country/Region': 'Nigeria',
#  'Lat': '9.082',
#  'Long': '8.6753',
#  'Province/State': ''}
# {'2020': 12512354027,
#  '2021': 86696208598,
#  '2022': 197806003111,
#  '2023': 45865034641,
#  'Country/Region': 'North Macedonia',
#  'Lat': '41.6086',
#  'Long': '21.7453',
#  'Province/State': ''}
# {'2020': 12512426538,
#  '2021': 86696498076,
#  '2022': 197807172088,
#  '2023': 45865379159,
#  'Country/Region': 'Norway',
#  'Lat': '60.472',
#  'Long': '8.4689',
#  'Province/State': ''}
# {'2020': 12512600954,
#  '2021': 86697572511,
#  '2022': 197808793988,
#  '2023': 45865693863,
#  'Country/Region': 'Oman',
#  'Lat': '21.512583',
#  'Long': '55.923255',
#  'Province/State': ''}
# {'2020': 12513981238,
#  '2021': 86705331960,
#  '2022': 197819859574,
#  '2023': 45867777408,
#  'Country/Region': 'Pakistan',
#  'Lat': '30.3753',
#  'Long': '69.3451',
#  'Province/State': ''}
# {'2020': 12513981238,
#  '2021': 86705331960,
#  '2022': 197819861610,
#  '2023': 45867778020,
#  'Country/Region': 'Palau',
#  'Lat': '7.515',
#  'Long': '134.5825',
#  'Province/State': ''}
# {'2020': 12514432306,
#  '2021': 86707708246,
#  '2022': 197822879739,
#  '2023': 45868362403,
#  'Country/Region': 'Panama',
#  'Lat': '8.538',
#  'Long': '-80.7821',
#  'Province/State': ''}
# {'2020': 12514433272,
#  '2021': 86707779903,
#  '2022': 197823117051,
#  '2023': 45868407933,
#  'Country/Region': 'Papua New Guinea',
#  'Lat': '-6.314993',
#  'Long': '143.95555',
#  'Province/State': ''}
# {'2020': 12514603143,
#  '2021': 86711684647,
#  '2022': 197830015830,
#  '2023': 45869754670,
#  'Country/Region': 'Paraguay',
#  'Lat': '-23.4425',
#  'Long': '-58.4438',
#  'Province/State': ''}
# {'2020': 12529879777,
#  '2021': 86774398703,
#  '2022': 197907884971,
#  '2023': 45884644688,
#  'Country/Region': 'Peru',
#  'Lat': '-9.19',
#  'Long': '-75.0152',
#  'Province/State': ''}
# {'2020': 12530928026,
#  '2021': 86784210208,
#  '2022': 197929911477,
#  '2023': 45889120705,
#  'Country/Region': 'Philippines',
#  'Lat': '12.879721',
#  'Long': '121.774017',
#  'Province/State': ''}
# {'2020': 12532350360,
#  '2021': 86808604564,
#  '2022': 197971821345,
#  '2023': 45897195641,
#  'Country/Region': 'Poland',
#  'Lat': '51.9194',
#  'Long': '19.1451',
#  'Province/State': ''}
# {'2020': 12532965716,
#  '2021': 86814674837,
#  '2022': 197980337526,
#  '2023': 45898963733,
#  'Country/Region': 'Portugal',
#  'Lat': '39.3999',
#  'Long': '-8.2245',
#  'Province/State': ''}
# {'2020': 12533007028,
#  '2021': 86814854040,
#  '2022': 197980583525,
#  '2023': 45899010371,
#  'Country/Region': 'Qatar',
#  'Lat': '25.3548',
#  'Long': '51.1839',
#  'Province/State': ''}
# {'2020': 12534255321,
#  '2021': 86827125976,
#  '2022': 198004404519,
#  '2023': 45903605655,
#  'Country/Region': 'Romania',
#  'Lat': '45.9432',
#  'Long': '24.9668',
#  'Province/State': ''}
# {'2020': 12539207980,
#  '2021': 86883278612,
#  '2022': 198137952143,
#  '2023': 45929936326,
#  'Country/Region': 'Russia',
#  'Lat': '61.52401',
#  'Long': '105.318756',
#  'Province/State': ''}
# {'2020': 12539213340,
#  '2021': 86883537537,
#  '2022': 198138484002,
#  '2023': 45930036148,
#  'Country/Region': 'Rwanda',
#  'Lat': '-1.9403',
#  'Long': '29.8739',
#  'Province/State': ''}
# {'2020': 12539213340,
#  '2021': 86883540264,
#  '2022': 198138499659,
#  '2023': 45930039286,
#  'Country/Region': 'Saint Kitts and Nevis',
#  'Lat': '17.357822',
#  'Long': '-62.782998',
#  'Province/State': ''}
# {'2020': 12539213500,
#  '2021': 86883583851,
#  '2022': 198138637217,
#  '2023': 45930067098,
#  'Country/Region': 'Saint Lucia',
#  'Lat': '13.9094',
#  'Long': '-60.9789',
#  'Province/State': ''}
# {'2020': 12539213500,
#  '2021': 86883592516,
#  '2022': 198138677092,
#  '2023': 45930075414,
#  'Country/Region': 'Saint Vincent and the Grenadines',
#  'Lat': '12.9843',
#  'Long': '-61.2872',
#  'Province/State': ''}
# {'2020': 12539213500,
#  '2021': 86883592516,
#  '2022': 198138684262,
#  '2023': 45930077386,
#  'Country/Region': 'Samoa',
#  'Lat': '-13.759',
#  'Long': '-172.1046',
#  'Province/State': ''}
# {'2020': 12539225517,
#  '2021': 86883623848,
#  '2022': 198138726269,
#  '2023': 45930085666,
#  'Country/Region': 'San Marino',
#  'Lat': '43.9424',
#  'Long': '12.4578',
#  'Province/State': ''}
# {'2020': 12539228927,
#  '2021': 86883637964,
#  '2022': 198138753179,
#  '2023': 45930090902,
#  'Country/Region': 'Sao Tome and Principe',
#  'Lat': '0.1864',
#  'Long': '6.6131',
#  'Province/State': ''}
# {'2020': 12540098564,
#  '2021': 86886450995,
#  '2022': 198142111745,
#  '2023': 45930742062,
#  'Country/Region': 'Saudi Arabia',
#  'Lat': '23.885942',
#  'Long': '45.079162',
#  'Province/State': ''}
# {'2020': 12540154076,
#  '2021': 86886935525,
#  '2022': 198142827741,
#  '2023': 45930876003,
#  'Country/Region': 'Senegal',
#  'Lat': '14.4974',
#  'Long': '-14.4524',
#  'Province/State': ''}
# {'2020': 12540360908,
#  '2021': 86889572019,
#  '2022': 198148691640,
#  '2023': 45932079907,
#  'Country/Region': 'Serbia',
#  'Lat': '44.0165',
#  'Long': '21.0059',
#  'Province/State': ''}
# {'2020': 12540360908,
#  '2021': 86889595603,
#  '2022': 198148751730,
#  '2023': 45932091603,
#  'Country/Region': 'Seychelles',
#  'Lat': '-4.6796',
#  'Long': '55.492',
#  'Province/State': ''}
# {'2020': 12540376446,
#  '2021': 86889632027,
#  '2022': 198148797481,
#  '2023': 45932100171,
#  'Country/Region': 'Sierra Leone',
#  'Lat': '8.460555',
#  'Long': '-11.779889',
#  'Province/State': ''}
# {'2020': 12540383241,
#  '2021': 86889691578,
#  '2022': 198149305419,
#  '2023': 45932217110,
#  'Country/Region': 'Singapore',
#  'Lat': '1.2833',
#  'Long': '103.8333',
#  'Province/State': ''}
# {'2020': 12540449908,
#  '2021': 86893752324,
#  '2022': 198156516327,
#  '2023': 45933641281,
#  'Country/Region': 'Slovakia',
#  'Lat': '48.669',
#  'Long': '19.699',
#  'Province/State': ''}
# {'2020': 12540568217,
#  '2021': 86895337629,
#  '2022': 198158920211,
#  '2023': 45934120915,
#  'Country/Region': 'Slovenia',
#  'Lat': '46.1512',
#  'Long': '14.9955',
#  'Province/State': ''}
# {'2020': 12540568217,
#  '2021': 86895337629,
#  '2022': 198158967045,
#  '2023': 45934131319,
#  'Country/Region': 'Solomon Islands',
#  'Lat': '-9.6457',
#  'Long': '160.1562',
#  'Province/State': ''}
# {'2020': 12540591642,
#  '2021': 86895624039,
#  '2022': 198159462380,
#  '2023': 45934223867,
#  'Country/Region': 'Somalia',
#  'Lat': '5.152149',
#  'Long': '46.199616',
#  'Province/State': ''}
# {'2020': 12543559793,
#  '2021': 86920017262,
#  '2022': 198196156138,
#  '2023': 45941199779,
#  'Country/Region': 'South Africa',
#  'Lat': '-30.5595',
#  'Long': '22.9375',
#  'Province/State': ''}
# {'2020': 12543570285,
#  '2021': 86920058260,
#  '2022': 198196206418,
#  '2023': 45941209163,
#  'Country/Region': 'South Sudan',
#  'Lat': '6.877',
#  'Long': '31.307',
#  'Province/State': ''}
# {'2020': 12552290382,
#  '2021': 86948703177,
#  '2022': 198235357158,
#  '2023': 45949267610,
#  'Country/Region': 'Spain',
#  'Lat': '40.463667',
#  'Long': '-3.74922',
#  'Province/State': ''}
# {'2020': 12552299630,
#  '2021': 86950811849,
#  '2022': 198241357829,
#  '2023': 45950411786,
#  'Country/Region': 'Sri Lanka',
#  'Lat': '7.873054',
#  'Long': '80.771797',
#  'Province/State': ''}
# {'2020': 12552489128,
#  '2021': 86951743780,
#  '2022': 198243076988,
#  '2023': 45950752114,
#  'Country/Region': 'Sudan',
#  'Lat': '12.8628',
#  'Long': '30.2176',
#  'Province/State': ''}
# {'2020': 12552489128,
#  '2021': 86951743780,
#  '2022': 198243076988,
#  '2023': 45950752114,
#  'Country/Region': 'Summer Olympics 2020',
#  'Lat': '35.6491',
#  'Long': '139.7737',
#  'Province/State': ''}
# {'2020': 12552504608,
#  '2021': 86951949070,
#  '2022': 198243568938,
#  '2023': 45950847286,
#  'Country/Region': 'Suriname',
#  'Lat': '3.9193',
#  'Long': '-56.0278',
#  'Province/State': ''}
# {'2020': 12553943176,
#  '2021': 86957052192,
#  '2022': 198250511441,
#  '2023': 45952422239,
#  'Country/Region': 'Sweden',
#  'Lat': '60.128161',
#  'Long': '18.643501',
#  'Province/State': ''}
# {'2020': 12554637789,
#  '2021': 86960935451,
#  '2022': 198255503190,
#  '2023': 45953388895,
#  'Country/Region': 'Switzerland',
#  'Lat': '46.8182',
#  'Long': '8.2275',
#  'Province/State': ''}
# {'2020': 12554681228,
#  '2021': 86961598694,
#  '2022': 198256644069,
#  '2023': 45953604035,
#  'Country/Region': 'Syria',
#  'Lat': '34.802075',
#  'Long': '38.996815',
#  'Province/State': ''}
# {'2020': 12554683167,
#  '2021': 86961765652,
#  '2022': 198259017889,
#  '2023': 45954735093,
#  'Country/Region': 'Taiwan*',
#  'Lat': '23.7',
#  'Long': '121.0',
#  'Province/State': ''}
# {'2020': 12554699191,
#  '2021': 86961804594,
#  '2022': 198259063514,
#  '2023': 45954743593,
#  'Country/Region': 'Tajikistan',
#  'Lat': '38.861',
#  'Long': '71.2761',
#  'Province/State': ''}
# {'2020': 12554704473,
#  '2021': 86961878796,
#  '2022': 198259364002,
#  '2023': 45954801111,
#  'Country/Region': 'Tanzania',
#  'Lat': '-6.369028',
#  'Long': '34.888822',
#  'Province/State': ''}
# {'2020': 12554720038,
#  '2021': 86964566576,
#  '2022': 198270018318,
#  '2023': 45957102003,
#  'Country/Region': 'Thailand',
#  'Lat': '15.870032',
#  'Long': '100.992541',
#  'Province/State': ''}
# {'2020': 12554720038,
#  '2021': 86964583547,
#  '2022': 198270066657,
#  '2023': 45957111387,
#  'Country/Region': 'Timor-Leste',
#  'Lat': '-8.874217',
#  'Long': '125.727539',
#  'Province/State': ''}
# {'2020': 12554728802,
#  '2021': 86964640265,
#  '2022': 198270167955,
#  '2023': 45957131107,
#  'Country/Region': 'Togo',
#  'Lat': '8.6195',
#  'Long': '0.8248',
#  'Province/State': ''}
# {'2020': 12554728802,
#  '2021': 86964640265,
#  '2022': 198270171222,
#  '2023': 45957131980,
#  'Country/Region': 'Tonga',
#  'Lat': '-21.179',
#  'Long': '-175.1982',
#  'Province/State': ''}
# {'2020': 12554741892,
#  '2021': 86964980001,
#  '2022': 198271604747,
#  '2023': 45957425842,
#  'Country/Region': 'Trinidad and Tobago',
#  'Lat': '10.6918',
#  'Long': '-61.2225',
#  'Province/State': ''}
# {'2020': 12554967182,
#  '2021': 86970960790,
#  '2022': 198282004071,
#  '2023': 45959418843,
#  'Country/Region': 'Tunisia',
#  'Lat': '33.886917',
#  'Long': '9.537499',
#  'Province/State': ''}
# {'2020': 12557030715,
#  '2021': 86989127119,
#  '2022': 198317681467,
#  '2023': 45966320299,
#  'Country/Region': 'Turkey',
#  'Lat': '38.9637',
#  'Long': '35.2433',
#  'Province/State': ''}
# {'2020': 12557030715,
#  '2021': 86989127119,
#  '2022': 198317681467,
#  '2023': 45966320299,
#  'Country/Region': 'Tuvalu',
#  'Lat': '-7.1095',
#  'Long': '177.6493',
#  'Province/State': ''}
# {'2020': 12603842626,
#  '2021': 87212595872,
#  '2022': 198685806999,
#  '2023': 46041791318,
#  'Country/Region': 'US',
#  'Lat': '40.0',
#  'Long': '-100.0',
#  'Province/State': ''}
# {'2020': 12603859378,
#  '2021': 87213210093,
#  '2022': 198687119671,
#  '2023': 46042038158,
#  'Country/Region': 'Uganda',
#  'Lat': '1.373333',
#  'Long': '32.290275',
#  'Province/State': ''}
# {'2020': 12605099416,
#  '2021': 87232631111,
#  '2022': 198729087028,
#  '2023': 46050130346,
#  'Country/Region': 'Ukraine',
#  'Lat': '48.3794',
#  'Long': '31.1656',
#  'Province/State': ''}
# {'2020': 12605199035,
#  '2021': 87233254638,
#  '2022': 198729930910,
#  '2023': 46050290030,
#  'Country/Region': 'United Arab Emirates',
#  'Lat': '23.424076',
#  'Long': '53.847818',
#  'Province/State': ''}
# {'2020': 12605199035,
#  '2021': 87233254886,
#  '2022': 198729934518,
#  '2023': 46050290846,
#  'Country/Region': 'United Kingdom',
#  'Lat': '18.2206',
#  'Long': '-63.0686',
#  'Province/State': 'Anguilla'}
# {'2020': 12605201339,
#  '2021': 87233271073,
#  '2022': 198729984679,
#  '2023': 46050301551,
#  'Country/Region': 'United Kingdom',
#  'Lat': '32.3078',
#  'Long': '-64.7505',
#  'Province/State': 'Bermuda'}
# {'2020': 12605201596,
#  '2021': 87233277347,
#  '2022': 198730006973,
#  '2023': 46050305903,
#  'Country/Region': 'United Kingdom',
#  'Lat': '18.4207',
#  'Long': '-64.64',
#  'Province/State': 'British Virgin Islands'}
# {'2020': 12605201933,
#  '2021': 87233278327,
#  '2022': 198730016927,
#  '2023': 46050308419,
#  'Country/Region': 'United Kingdom',
#  'Lat': '19.3133',
#  'Long': '-81.2546',
#  'Province/State': 'Cayman Islands'}
# {'2020': 12605201933,
#  '2021': 87233278327,
#  '2022': 198730016927,
#  '2023': 46050308419,
#  'Country/Region': 'United Kingdom',
#  'Lat': '49.3723',
#  'Long': '-2.3644',
#  'Province/State': 'Channel Islands'}
# {'2020': 12605201933,
#  '2021': 87233278327,
#  '2022': 198730016927,
#  '2023': 46050308419,
#  'Country/Region': 'United Kingdom',
#  'Lat': '-51.7963',
#  'Long': '-59.5236',
#  'Province/State': 'Falkland Islands (Malvinas)'}
# {'2020': 12605202170,
#  '2021': 87233311201,
#  '2022': 198730055087,
#  '2023': 46050315962,
#  'Country/Region': 'United Kingdom',
#  'Lat': '36.1408',
#  'Long': '-5.3536',
#  'Province/State': 'Gibraltar'}
# {'2020': 12605206403,
#  '2021': 87233317969,
#  '2022': 198730073099,
#  '2023': 46050320454,
#  'Country/Region': 'United Kingdom',
#  'Lat': '49.448196',
#  'Long': '-2.58949',
#  'Province/State': 'Guernsey'}
# {'2020': 12605212547,
#  '2021': 87233331810,
#  '2022': 198730110201,
#  '2023': 46050328342,
#  'Country/Region': 'United Kingdom',
#  'Lat': '54.2361',
#  'Long': '-4.5481',
#  'Province/State': 'Isle of Man'}
# {'2020': 12605220473,
#  '2021': 87233358140,
#  '2022': 198730156584,
#  '2023': 46050339017,
#  'Country/Region': 'United Kingdom',
#  'Lat': '49.2138',
#  'Long': '-2.1358',
#  'Province/State': 'Jersey'}
# {'2020': 12605220725,
#  '2021': 87233358505,
#  '2022': 198730158598,
#  '2023': 46050339561,
#  'Country/Region': 'United Kingdom',
#  'Lat': '16.742498',
#  'Long': '-62.187366',
#  'Province/State': 'Montserrat'}
# {'2020': 12605220725,
#  '2021': 87233358505,
#  '2022': 198730158598,
#  '2023': 46050339561,
#  'Country/Region': 'United Kingdom',
#  'Lat': '-24.3768',
#  'Long': '-128.3242',
#  'Province/State': 'Pitcairn Islands'}
# {'2020': 12605220729,
#  '2021': 87233358505,
#  '2022': 198730158598,
#  '2023': 46050339561,
#  'Country/Region': 'United Kingdom',
#  'Lat': '-7.9467',
#  'Long': '-14.3559',
#  'Province/State': 'Saint Helena, Ascension and Tristan da Cunha'}
# {'2020': 12605221650,
#  '2021': 87233365067,
#  '2022': 198730171534,
#  '2023': 46050342111,
#  'Country/Region': 'United Kingdom',
#  'Lat': '21.694',
#  'Long': '-71.7979',
#  'Province/State': 'Turks and Caicos Islands'}
# {'2020': 12621030697,
#  '2021': 87289864783,
#  '2022': 198803378802,
#  '2023': 46065237008,
#  'Country/Region': 'United Kingdom',
#  'Lat': '55.3781',
#  'Long': '-3.436',
#  'Province/State': ''}
# {'2020': 12621042962,
#  '2021': 87291335575,
#  '2022': 198806016093,
#  '2023': 46065754031,
#  'Country/Region': 'Uruguay',
#  'Lat': '-32.5228',
#  'Long': '-55.7658',
#  'Province/State': ''}
# {'2020': 12621118576,
#  '2021': 87291668368,
#  '2022': 198806608995,
#  '2023': 46065865347,
#  'Country/Region': 'Uzbekistan',
#  'Lat': '41.377491',
#  'Long': '64.585262',
#  'Province/State': ''}
# {'2020': 12621118576,
#  '2021': 87291668623,
#  '2022': 198806612727,
#  '2023': 46065866299,
#  'Country/Region': 'Vanuatu',
#  'Lat': '-15.3767',
#  'Long': '166.9592',
#  'Province/State': ''}
# {'2020': 12621225071,
#  '2021': 87292809696,
#  '2022': 198808697744,
#  '2023': 46066263761,
#  'Country/Region': 'Venezuela',
#  'Lat': '6.4238',
#  'Long': '-66.5897',
#  'Province/State': ''}
# {'2020': 12621229979,
#  '2021': 87295746395,
#  '2022': 198824029845,
#  '2023': 46069200409,
#  'Country/Region': 'Vietnam',
#  'Lat': '14.058324',
#  'Long': '108.277199',
#  'Province/State': ''}
# {'2020': 12621304900,
#  '2021': 87296997524,
#  '2022': 198826070360,
#  '2023': 46069588553,
#  'Country/Region': 'West Bank and Gaza',
#  'Lat': '31.9522',
#  'Long': '35.2332',
#  'Province/State': ''}
# {'2020': 12621304900,
#  '2021': 87296997524,
#  '2022': 198826070360,
#  '2023': 46069588553,
#  'Country/Region': 'Winter Olympics 2022',
#  'Lat': '39.9042',
#  'Long': '116.4074',
#  'Province/State': ''}
# {'2020': 12621413844,
#  '2021': 87297478430,
#  '2022': 198826849144,
#  '2023': 46069735365,
#  'Country/Region': 'Yemen',
#  'Lat': '15.552727',
#  'Long': '48.516388',
#  'Province/State': ''}
# {'2020': 12621466886,
#  '2021': 87298328358,
#  '2022': 198828302853,
#  '2023': 46070010408,
#  'Country/Region': 'Zambia',
#  'Lat': '-13.133897',
#  'Long': '27.849332',
#  'Province/State': ''}
# {'2020': 12621503569,
#  '2021': 87299357858,
#  '2022': 198830313008,
#  '2023': 46070394787,
#  'Country/Region': 'Zimbabwe',
#  'Lat': '-19.015438',
#  'Long': '29.154857',
#  'Province/State': ''}
#
# RESPONSE: (289, [])

# %%
url = 'http://elastic:secret@localhost:9200/covid_db_deaths_global/_search'

# %%
#elastic.delete_by_query(index='_all', body={"query": {"match_all": {}}})

# %%
 
elastic.indices.refresh(index="covid_db_recovered_global")

res = elastic.search(index="covid_db_recovered_global", body={"from" : 0, "size" : 1000,"query": {"match_all": {}}})
print(len(res['hits']['hits']))
print(res)
# Out:
# 274
# {'took': 9, 'timed_out': False, '_shards': {'total': 5, 'successful': 5, 'skipped': 0, 'failed': 0}, 'hits': {'total': 274, 'max_score': 1.0, 'hits': [{'_index': 'covid_db_recovered_global', '_type': 'recovered_global', '_id': '9a23263a-996c-449c-8535-01c80f86fff9', '_score': 1.0, '_source': {'Province/State': '', 'Country/Region': 'Albania', 'Lat': '41.1533', 'Long': '20.1683', '2020': 7650563688, '2021': 67164662438, '2022': 196529309166, '2023': 45606703559}}, {'_index': 'covid_db_recovered_global', '_type': 'recovered_global', '_id': '3b2a3c08-2d36-4a1f-bb6f-baf1327ba1f9', '_score': 1.0, '_source': {'Province/State': '', 'Country/Region': 'Angola', 'Lat': '-11.2027', 'Long': '17.8739', '2020': 7658908868, '2021': 67190968940, '2022': 196529309166, '2023': 45606703559}}, {'_index': 'covid_db_recovered_global', '_type': 'recovered_global', '_id': 'caae5081-b678-4815-b1c2-e31dd29ced03', '_score': 1.0, '_source': {'Province/State': 'South Australia', 'Country/Region': 'Australia', 'Lat': '-34.9285', 'Long': '138.6007', '2020': 7792167519, '2021': 67822390989, '2022': 196529309166, '2023': 45606703559}}, {'_index': 'covid_db_recovered_global', '_type': 'recovered_global', '_id': '5e278d9f-6a79-47df-bf86-0114ba8c23b8', '_score': 1.0, '_source': {'Province/State': '', 'Country/Region': 'Azerbaijan', 'Lat': '40.1431', 'Long': '47.5769', '2020': 7822623860, '2021': 68000020644, '2022': 196529309166, '2023': 45606703559}}, {'_index': 'covid_db_recovered_global', '_type': 'recovered_global', '_id': '352f2c00-4e98-48ef-b80a-b1d07eb74525', '_score': 1.0, '_source': {'Province/State': '', 'Country/Region': 'Belize', 'Lat': '17.1899', 'Long': '-88.4976', '2020': 7906133681, '2021': 68254092285, '2022': 196529309166, '2023': 45606703559}}, {'_index': 'covid_db_recovered_global', '_type': 'recovered_global', '_id': 'a42857ba-9c6a-488e-887a-91f373000b94', '_score': 1.0, '_source': {'Province/State': '', 'Country/Region': 'Bolivia', 'Lat': '-16.2902', 'Long': '-63.5887', '2020': 7921579955, '2021': 68310561170, '2022': 196529309166, '2023': 45606703559}}, {'_index': 'covid_db_recovered_global', '_type': 'recovered_global', '_id': 'a196b3ff-ac4c-4cfa-b910-d6951bab8f2c', '_score': 1.0, '_source': {'Province/State': '', 'Country/Region': 'Bosnia and Herzegovina', 'Lat': '43.9159', 'Long': '17.6791', '2020': 7926617269, '2021': 68341457264, '2022': 196529309166, '2023': 45606703559}}, {'_index': 'covid_db_recovered_global', '_type': 'recovered_global', '_id': 'f269fe43-5d6f-498f-bd3c-ec54a2eb44cd', '_score': 1.0, '_source': {'Province/State': '', 'Country/Region': 'Brazil', 'Lat': '-14.235', 'Long': '-51.9253', '2020': 8681354426, '2021': 71008771283, '2022': 196529309166, '2023': 45606703559}}, {'_index': 'covid_db_recovered_global', '_type': 'recovered_global', '_id': '3ae05207-c603-4885-99aa-44e66902d23d', '_score': 1.0, '_source': {'Province/State': '', 'Country/Region': 'Burma', 'Lat': '21.9162', 'Long': '95.956', '2020': 8691825246, '2021': 71104039408, '2022': 196529309166, '2023': 45606703559}}, {'_index': 'covid_db_recovered_global', '_type': 'recovered_global', '_id': 'aa3400b3-5cca-4c4e-ba13-b2239e0d5a7a', '_score': 1.0, '_source': {'Province/State': '', 'Country/Region': 'Chad', 'Lat': '15.4542', 'Long': '18.7322', '2020': 8735317501, '2021': 71347908735, '2022': 196529309166, '2023': 45606703559}}, {'_index': 'covid_db_recovered_global', '_type': 'recovered_global', '_id': '4188232e-cc12-4e6a-9b03-d99c75716b79', '_score': 1.0, '_source': {'Province/State': '', 'Country/Region': 'Chile', 'Lat': '-35.6751', 'Long': '-71.543', '2020': 8819959966, '2021': 71579646673, '2022': 196529309166, '2023': 45606703559}}, {'_index': 'covid_db_recovered_global', '_type': 'recovered_global', '_id': 'bac926a9-5b5a-44e1-b533-27d9b54e0160', '_score': 1.0, '_source': {'Province/State': 'Gansu', 'Country/Region': 'China', 'Lat': '35.7518', 'Long': '104.2861', '2020': 8820846257, '2021': 71580373901, '2022': 196529309166, '2023': 45606703559}}, {'_index' ...

# %% [markdown]
# # elastic to cassandra

# %%
#!pip3 install cassandra-driver
# Out:
# Requirement already satisfied: cassandra-driver in c:\users\flore\anaconda3\lib\site-packages (3.25.0)
# Requirement already satisfied: geomet<0.3,>=0.1 in c:\users\flore\anaconda3\lib\site-packages (from cassandra-driver) (0.2.1.post1)
# Requirement already satisfied: six>=1.9 in c:\users\flore\anaconda3\lib\site-packages (from cassandra-driver) (1.15.0)
# Requirement already satisfied: click in c:\users\flore\anaconda3\lib\site-packages (from geomet<0.3,>=0.1->cassandra-driver) (7.1.2)

# %%
print(data)
# Out:
# {'time_series_covid19_confirmed_global': [{'Province/State': '', 'Country/Region': 'Afghanistan', 'Lat': '33.93911', 'Long': '67.709953', '2020': 8501751, '2021': 39518380, '2022': 67783564, '2023': 14184774}, {'Province/State': '', 'Country/Region': 'Albania', 'Lat': '41.1533', 'Long': '20.1683', '2020': 12229295, '2021': 90624521, '2022': 175788238, '2023': 36909069}, {'Province/State': '', 'Country/Region': 'Algeria', 'Lat': '28.0339', 'Long': '1.6596', '2020': 22812670, '2021': 147797509, '2022': 272320311, '2023': 55362283}, {'Province/State': '', 'Country/Region': 'Andorra', 'Lat': '42.5063', 'Long': '1.5218', '2020': 23495492, '2021': 152881839, '2022': 287848049, '2023': 58614918}, {'Province/State': '', 'Country/Region': 'Angola', 'Lat': '-11.2027', 'Long': '17.8739', '2020': 24838902, '2021': 167678984, '2022': 324581126, '2023': 65766489}, {'Province/State': '', 'Country/Region': 'Antarctica', 'Lat': '-71.9499', 'Long': '23.347', '2020': 24838902, '2021': 167679182, '2022': 324585141, '2023': 65767237}, {'Province/State': '', 'Country/Region': 'Antigua and Barbuda', 'Lat': '17.0608', 'Long': '-61.7964', '2020': 24861804, '2021': 168368620, '2022': 327563848, '2023': 66386445}, {'Province/State': '', 'Country/Region': 'Argentina', 'Lat': '-38.4161', 'Long': '-63.6167', '2020': 173198225, '2021': 1608579680, '2022': 3682802830, '2023': 748082903}, {'Province/State': '', 'Country/Region': 'Armenia', 'Lat': '40.0691', 'Long': '45.0382', '2020': 187751302, '2021': 1694821197, '2022': 3837153028, '2023': 778429434}, {'Province/State': 'Australian Capital Territory', 'Country/Region': 'Australia', 'Lat': '-35.4735', 'Long': '149.0124', '2020': 187782417, '2021': 1695058000, '2022': 3889218227, '2023': 794098837}, {'Province/State': 'New South Wales', 'Country/Region': 'Australia', 'Lat': '-33.8688', 'Long': '151.2093', '2020': 188844816, '2021': 1706093814, '2022': 4848556205, '2023': 1057760677}, {'Province/State': 'Northern Territory', 'Country/Region': 'Australia', 'Lat': '-12.4634', 'Long': '130.8456', '2020': 188854935, '2021': 1706161190, '2022': 4874775205, '2023': 1064859140}, {'Province/State': 'Queensland', 'Country/Region': 'Australia', 'Lat': '-27.4698', 'Long': '153.0251', '2020': 189166671, '2021': 1706847652, '2022': 5310430512, '2023': 1186044799}, {'Province/State': 'South Australia', 'Country/Region': 'Australia', 'Lat': '-34.9285', 'Long': '138.6007', '2020': 189299507, '2021': 1707183741, '2022': 5503728060, '2023': 1245502894}, {'Province/State': 'Tasmania', 'Country/Region': 'Australia', 'Lat': '-42.8821', 'Long': '147.3272', '2020': 189360961, '2021': 1707272207, '2022': 5566228114, '2023': 1264849786}, {'Province/State': 'Victoria', 'Country/Region': 'Australia', 'Lat': '-37.8136', 'Long': '144.9631', '2020': 192656986, '2021': 1722881158, '2022': 6280325819, '2023': 1459543357}, {'Province/State': 'Western Australia', 'Country/Region': 'Australia', 'Lat': '-31.9505', 'Long': '115.8605', '2020': 192842526, '2021': 1723254820, '2022': 6544218087, '2023': 1546704409}, {'Province/State': '', 'Country/Region': 'Austria', 'Lat': '47.5162', 'Long': '14.5501', '2020': 214614435, '2021': 1972025880, '2022': 8088996373, '2023': 1941840788}, {'Province/State': '', 'Country/Region': 'Azerbaijan', 'Lat': '40.1431', 'Long': '47.5769', '2020': 227563467, '2021': 2109451731, '2022': 8375872024, '2023': 1998136915}, {'Province/State': '', 'Country/Region': 'Bahamas', 'Lat': '25.025885', 'Long': '-78.035889', '2020': 228337073, '2021': 2114801477, '2022': 8388701429, '2023': 2000686303}, {'Province/State': '', 'Country/Region': 'Bahrain', 'Lat': '26.0275', 'Long': '50.55', '2020': 241266779, '2021': 2194468209, '2022': 8605666451, '2023': 2048431526}, {'Province/State': '', 'Country/Region': 'Bangladesh', 'Lat': '23.685', 'Long': '90.3563', '2020': 310076257, '2021': 2581952099, '2022': 9320186589, '2023': 2186985701}, {'Province/State': '', 'Country/Region': 'Barbados', 'Lat': '13.1939', 'Long': '-59.5432', '2020': ...

# %%
from cassandra.cluster import Cluster
from cassandra.auth import PlainTextAuthProvider
import json

def get_elastic_hits(elastic, index):  
    elastic.indices.refresh(index)
    res = elastic.search(index, body={"query": {"match_all": {}}})
    hits = res['hits']['hits']
    return hits

covid_index_names = []
indices=elastic.indices.get_alias().keys()
for indice in indices:
    if indice.startswith("covid") and indice not in covid_index_names:
        covid_index_names.append(indice)
#print(covid_index_names)

# Set up authentication credentials (if needed)
auth_provider = PlainTextAuthProvider(username='elastic', password='secret')

# Set up a Cluster object with the contact points (IP addresses or hostnames) of the Cassandra nodes
cluster = Cluster(['localhost'])

# Connect to the cluster and create a session
session = cluster.connect()

#create keySpace covid
keyspace_stmt = "CREATE KEYSPACE IF NOT EXISTS covid19 WITH replication = {'class': 'SimpleStrategy', 'replication_factor': 1}"
session.execute(keyspace_stmt)

#create table
def create_covid_table(table_name):
        query = f"CREATE TABLE IF NOT EXISTS covid19.{table_name} (id varchar PRIMARY KEY, type text, score float, province text, country text, lat text, long text, year_2020 float, year_2021 float, year_2022 float, year_2023 float)"
        session.execute(query)
        
#insert into table
def insert_data_in_cassandra(table,hits):
    # Insert the data into Cassandra Datastax
    for hit in hits:
        cql_query = f"INSERT INTO covid19.{table}(id, type, score, province, country, lat, long , year_2020, year_2021, year_2022, year_2023) VALUES('{hit['_id']}', '{hit['_type']}',{hit['_score']},'{hit['_source']['Province/State']}','{hit['_source']['Country/Region']}', '{hit['_source']['Lat']}', '{hit['_source']['Long']}', {hit['_source']['2020']},{hit['_source']['2021']},{hit['_source']['2022']}, {hit['_source']['2023']})"
       # print(cql_query)
        session.execute(cql_query)         
    return 0



# Execution des 3 indexs

indexes=[
    "covid_db_recovered_global",
    "covid_db_deaths_global",
   "covid_db_confirmed_global"
    ]
for indice in indexes:
    hits=get_elastic_hits(elastic, indice)
    create_covid_table(indice)
    insert_data_in_cassandra(indice,hits)
    


# result=(session.execute('SELECT * FROM covid19.covid_db_recovered_global;') )
# print(result.__dict__)
# print(result.__dict__['_current_rows'])
# #hits = get_elastic_hits(elastic, "covid_db_deaths_global")



# fermer les sessions cassandra 
session.shutdown()
cluster.shutdown()

# %% [markdown]
# # Visualisation Kibana

# %%
covid_index_names = []
indices=elastic.indices.get_alias().keys()
for indice in indices:
    if indice.startswith("covid") and indice not in covid_index_names:
        covid_index_names.append(indice)
print(covid_index_names)
# Out:
# ['covid_db_confirmed_global', 'covid_db_deaths_global', 'covid_db_recovered_global']

# %%
import json, requests
from requests.auth import HTTPBasicAuth

id=0
for i in covid_index_names:
    print(i)
    id=id+1
    payload={
        "attributes":{
        "title":i+"*"
        }
    }
    ret = requests.post("http://localhost:5601/api/saved_objects/index-pattern/"+str(id), headers={"kbn-xsrf":"true", "Content-Type": "application/json"}, auth=HTTPBasicAuth('elastic', 'secret'), json=payload)
    print(ret.text)
print(covid_index_names)
# Out:
# covid_db_deaths_global
# {"id":"1","type":"index-pattern","version":3,"attributes":{"title":"covid_db_deaths_global*"}}
# covid_db_recovered_global
# {"id":"2","type":"index-pattern","version":3,"attributes":{"title":"covid_db_recovered_global*"}}
# covid_db_confirmed_global
# {"id":"3","type":"index-pattern","version":3,"attributes":{"title":"covid_db_confirmed_global*"}}
# ['covid_db_deaths_global', 'covid_db_recovered_global', 'covid_db_confirmed_global']
